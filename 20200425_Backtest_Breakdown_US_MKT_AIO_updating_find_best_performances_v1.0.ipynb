# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

# %%
# 1. backtest.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
import pprint
try:
    import Queue as queue
except ImportError:
    import queue
import time

print("Executing backtest.py")
class Backtest(object):
    """
    Enscapsulates the settings and components for carrying out
    an event-driven backtest.
    """
#     print("*****backtest.py: 01: Class Backtest(object)*****")
    def __init__(
        self, csv_dir, symbol_list, initial_capital,
        heartbeat, start_date, data_handler, 
        execution_handler, portfolio, strategy
    ):
        """
        Initialises the backtest.
        Parameters:
        csv_dir - The hard root to the CSV data directory.
        symbol_list - The list of symbol strings.
        intial_capital - The starting capital for the portfolio.
        heartbeat - Backtest "heartbeat" in seconds
        start_date - The start datetime of the strategy.
        data_handler - (Class) Handles the market data feed.
        execution_handler - (Class) Handles the orders/fills for trades.
        portfolio - (Class) Keeps track of portfolio current and prior positions.
        strategy - (Class) Generates signals based on market data.
        """
#         print("*****backtest.py: 1. Backtest.initializing..*****")
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list
        self.initial_capital = initial_capital
        self.heartbeat = heartbeat
        self.start_date = start_date

        self.data_handler_cls = data_handler
        self.execution_handler_cls = execution_handler
        self.portfolio_cls = portfolio
        self.strategy_cls = strategy

        # Added by Brad on 20191006
        # self.plots_cls = plots

        self.events = queue.Queue()
        
        self.signals = 0
        self.orders = 0
        self.fills = 0
        self.num_strats = 1
       
        self._generate_trading_instances()

    def _generate_trading_instances(self):
        # function1: call0 classes of 1)DataHandler, 2)strategy, 3)portfolion, 4)ExecutionHandler
        """
        Generates the trading instance objects from 
        their class types.
        """
#         print("*****backtest.py: 2. Backtest._generate_trading_instances*****")
#         print(
#             "backtest.py: _generate_trading_instances: Creating DataHandler, Strategy, Portfolio and ExecutionHandler"
#         )
        self.data_handler = self.data_handler_cls(self.events, self.csv_dir, self.symbol_list)
        self.strategy = self.strategy_cls(self.data_handler, self.events)
        self.portfolio = self.portfolio_cls(self.data_handler, self.events, self.start_date, 
                                            self.initial_capital)
        self.execution_handler = self.execution_handler_cls(self.events)
    

    def _run_backtest(self): # 
        # function1: update market bars
        # function2: identify the current event, including 1)market, 2)signal, 3)order, 4)
        """
        Executes the backtest.
        """
#         print("*****backtest.py: 3. Backtest._run_backtest*****")
#         print("Running Backtest...")
        i = 0
        while True:
            i += 1
            # print(i)

            # Update the market bars
            if self.data_handler.continue_backtest == True:
                self.data_handler.update_bars()
            else:
                break

            # Handle the events
            while True:
                try:
                    event = self.events.get(False)
                except queue.Empty:
                    break
                else:
                    if event is not None:
                        if event.type == 'MARKET':
                            self.strategy.calculate_signals(event)
                            self.portfolio.update_timeindex(event)

                        elif event.type == 'SIGNAL':
                            self.signals += 1                            
                            self.portfolio.update_signal(event)

                        elif event.type == 'ORDER':
                            self.orders += 1
                            self.execution_handler.execute_order(event)

                        elif event.type == 'FILL':
                            self.fills += 1
                            self.portfolio.update_fill(event)

            time.sleep(self.heartbeat)

	# OG version
    # def _output_performance(self):
    #     """
    #     Outputs the strategy performance from the backtest.
    #     """
    #     self.portfolio.create_equity_curve_dataframe()
        
    #     print("Creating summary stats...")
    #     stats = self.portfolio.output_summary_stats()
        
    #     print("Creating equity curve...")
    #     print(self.portfolio.equity_curve.tail(10))
    #     pprint.pprint(stats)

    #     print("Signals: %s" % self.signals)
    #     print("Orders: %s" % self.orders)
    #     print("Fills: %s" % self.fills)


    def _output_performance(self):
        """
        Outputs the strategy performance from the backtest.
        """
        self.portfolio.create_equity_curve_dataframe()
#         print("*****backtest.py: 4. Backtest._output_performance*****")
        print("Creating summary stats...")
        stats = self.portfolio.output_summary_stats()
        
        print("Creating equity curve...")
        print(self.portfolio.equity_curve.tail(10))
        pprint.pprint(stats)

        print("Signals: %s" % self.signals)
        print("Orders: %s" % self.orders)
        print("Fills: %s" % self.fills)

    def simulate_trading(self):
        # function 1: call 1)_run _backtest, 2__output_formance
        """
        Simulates the backtest and outputs portfolio performance.
        """
#         print("*****backtest.py: 5. Backtest.simulate_trading*****")
        self._run_backtest()
        self._output_performance()
# Out:
# Executing backtest.py

# %%
# 2. event.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

print("Executing event.py")
class Event(object):
    """
    Event is base class providing an interface for all subsequent 
    (inherited) events, that will trigger further events in the 
    trading infrastructure.   
    """
#     print("*****event.py: 01 Class. Event(object)*****")
    pass


class MarketEvent(Event):
    """
    Handles the event of receiving a new market update with 
    corresponding bars.
    """
#     print("*****event.py: 02 Class. MarketEvent(Event)*****")
    def __init__(self):
        """
        Initialises the MarketEvent.
        """
#         print("*****event.py: 1. initializing..*****")
        self.type = 'MARKET'


class SignalEvent(Event):
    """
    Handles the event of sending a Signal from a Strategy object.
    This is received by a Portfolio object and acted upon.
    """
    print("*****event.py: 03 Class: SignalEvent(Event)*****")
    def __init__(self, strategy_id, symbol, datetime, signal_type, strength):
        """
        Initialises the SignalEvent.
        Parameters:
        strategy_id - The unique ID of the strategy sending the signal.
        symbol - The ticker symbol, e.g. 'GOOG'.
        datetime - The timestamp at which the signal was generated.
        signal_type - 'LONG' or 'SHORT'.
        strength - An adjustment factor "suggestion" used to scale 
            quantity at the portfolio level. Useful for pairs strategies.
        """
#         print("*****event.py: 1. SignalEvent.initializing..*****")
        self.strategy_id = strategy_id
        self.type = 'SIGNAL'
        self.symbol = symbol
        self.datetime = datetime
        self.signal_type = signal_type
        self.strength = strength


class OrderEvent(Event):
    """
    Handles the event of sending an Order to an execution system.
    The order contains a symbol (e.g. GOOG), a type (market or limit),
    quantity and a direction.
    """
    print("*****event.py: 04 Class: OrderEvent(Event)*****")
    def __init__(self, symbol, order_type, quantity, direction):
        """
        Initialises the order type, setting whether it is
        a Market order ('MKT') or Limit order ('LMT'), has
        a quantity (integral) and its direction ('BUY' or
        'SELL').
        TODO: Must handle error checking here to obtain 
        rational orders (i.e. no negative quantities etc).
        Parameters:
        symbol - The instrument to trade.
        order_type - 'MKT' or 'LMT' for Market or Limit.
        quantity - Non-negative integer for quantity.
        direction - 'BUY' or 'SELL' for long or short.
        """
#         print("*****event.py: 1. OrderEvent.initializing..*****")
        self.type = 'ORDER'
        self.symbol = symbol
        self.order_type = order_type
        self.quantity = quantity
        self.direction = direction

    def print_order(self):
        """
        Outputs the values within the Order.
        """
#         print("*****event.py: 2. OrderEvent.print_order*****")
        print(
            "Order: Symbol=%s, Type=%s, Quantity=%s, Direction=%s" % 
            (self.symbol, self.order_type, self.quantity, self.direction)
        )


class FillEvent(Event):
    """
    Encapsulates the notion of a Filled Order, as returned
    from a brokerage. Stores the quantity of an instrument
    actually filled and at what price. In addition, stores
    the commission of the trade from the brokerage.
    
    TODO: Currently does not support filling positions at
    different prices. This will be simulated by averaging
    the cost.
    """
#     print("*****event.py: 05 Class: FillEvent(Event)*****")
    def __init__(self, timeindex, symbol, exchange, quantity, 
                 direction, fill_cost, commission=None):
        """
        Initialises the FillEvent object. Sets the symbol, exchange,
        quantity, direction, cost of fill and an optional 
        commission.
        If commission is not provided, the Fill object will
        calculate it based on the trade size and Interactive
        Brokers fees.
        Parameters:
        timeindex - The bar-resolution when the order was filled.
        symbol - The instrument which was filled.
        exchange - The exchange where the order was filled.
        quantity - The filled quantity.
        direction - The direction of fill ('BUY' or 'SELL')
        fill_cost - The holdings value in dollars.
        commission - An optional commission sent from IB.
        """
#         print("*****event.py: 1. FillEvent.initializing..*****")
        self.type = 'FILL'
        self.timeindex = timeindex
        self.symbol = symbol
        self.exchange = exchange
        self.quantity = quantity
        self.direction = direction
        self.fill_cost = fill_cost

        # Calculate commission
        if commission is None:
            self.commission = self.calculate_ib_commission()
        else:
            self.commission = commission

    def calculate_ib_commission(self):
        """
        Calculates the fees of trading based on an Interactive
        Brokers fee structure for API, in USD.
        This does not include exchange or ECN fees.
        Based on "US API Directed Orders":
        https://www.interactivebrokers.com/en/index.php?f=commission&p=stocks2
        """
#         print("*****event.py: 2. FillEvent.calculate_ib_commission*****")
#         full_cost = 1.3
#         if self.quantity <= 500:
#             full_cost = max(1.3, 0.013 * self.quantity)
#         else: # Greater than 500
#             full_cost = max(1.3, 0.008 * self.quantity)
        full_cost = commissions
        return full_cost
# Out:
# Executing event.py
# *****event.py: 03 Class: SignalEvent(Event)*****
# *****event.py: 04 Class: OrderEvent(Event)*****

# %%
# 3. data.py
#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
import os, os.path

import numpy as np
import pandas as pd

# from event import MarketEvent

print("Executing data.py")
class DataHandler(object):
    """
    DataHandler is an abstract base class providing an interface for
    all subsequent (inherited) data handlers (both live and historic).
    The goal of a (derived) DataHandler object is to output a generated
    set of bars (OHLCVI) for each symbol requested. 
    This will replicate how a live strategy would function as current
    market data would be sent "down the pipe". Thus a historic and live
    system will be treated identically by the rest of the backtesting suite.
    """
#     print("*****data.py: 01 Class: Datahandler(object) ran, an abstract base class*****")
    __metaclass__ = ABCMeta

    @abstractmethod
    def get_latest_bar(self, symbol):
#         print("*****data.py: 1. DataHandler.get_latest_bar*****")
        """
        Returns the last bar updated.
        """
        raise NotImplementedError("Should implement get_latest_bar()")

    @abstractmethod
    def get_latest_bars(self, symbol, N=1):
#         print("*****data.py: 2. DataHandler.get_latest_bars*****")
        """
        Returns the last N bars updated.
        """
        raise NotImplementedError("Should implement get_latest_bars()")

    @abstractmethod
    def get_latest_bar_datetime(self, symbol):
#         print("*****data.py: 3. DataHandler.get_latest_bar_datetime*****")
        """
        Returns a Python datetime object for the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_datetime()")

    @abstractmethod
    def get_latest_bar_value(self, symbol, val_type):
#         print("*****data.py: 4. DataHandler.get_latest_bar_value*****")
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        from the last bar.
        """
        raise NotImplementedError("Should implement get_latest_bar_value()")

    @abstractmethod
    def get_latest_bars_values(self, symbol, val_type, N=1):
#         print("*****data.py: 5. DataHandler.get_latest_bars_values*****")
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
        raise NotImplementedError("Should implement get_latest_bars_values()")

    @abstractmethod
    def update_bars(self):
#         print("*****data.py: 6. DataHandler.update_bars*****")
        """
        Pushes the latest bars to the bars_queue for each symbol
        in a tuple OHLCVI format: (datetime, open, high, low, 
        close, volume, open interest).
        """
        raise NotImplementedError("Should implement update_bars()")


class HistoricCSVDataHandler(DataHandler):
    """
    HistoricCSVDataHandler is designed to read CSV files for
    each requested symbol from disk and provide an interface
    to obtain the "latest" bar in a manner identical to a live
    trading interface. 
    """
    print("*****data.py: 02 Class: HistoricCSVDataHandler(DataHandler)*****")
    def __init__(self, events, csv_dir, symbol_list):
        
#         print("*****data.py: 1. HistoricCSVDataHandler.initializing..")
        """
        Initialises the historic data handler by requesting
        the location of the CSV files and a list of symbols.
        It will be assumed that all files are of the form
        'symbol.csv', where symbol is a string in the list.
        Parameters:
        events - The Event Queue.
        csv_dir - Absolute directory path to the CSV files.
        symbol_list - A list of symbol strings.
        """
        self.events = events
        self.csv_dir = csv_dir
        self.symbol_list = symbol_list

        self.symbol_data = {}
        self.latest_symbol_data = {}
        self.continue_backtest = True       
        self.bar_index = 0

        self._open_convert_csv_files()

    def _open_convert_csv_files(self):
        """
        Opens the CSV files from the data directory, converting
        them into pandas DataFrames within a symbol dictionary.
        For this handler it will be assumed that the data is
        taken from Yahoo. Thus its format will be respected.
        """
#         print("*****data.py: 2. HistoricCSVDataHandler._open_convert_csv_files")
        comb_index = None
        
        for s in self.symbol_list:
            # Load the CSV file with no header information, indexed on date
            self.symbol_data[s] = pd.io.parsers.read_csv(
                os.path.join(self.csv_dir, '%s.csv' % s),
                header=0, index_col=0, parse_dates=True,
                names=data_cols
            )
            self.symbol_data[s].reset_index(inplace = True)
            self.symbol_data[s].set_index(date_col, inplace=True)
            # ).sort_values('date')
            # print("symbol_data",self.symbol_data[s])#######################
            # Combine the index to pad forward values
            if comb_index is None:
                comb_index = self.symbol_data[s].index
            else:
                comb_index.union(self.symbol_data[s].index)

            # Set the latest symbol_data to None
            self.latest_symbol_data[s] = []

        # Reindex the dataframes
        for s in self.symbol_list:
            self.symbol_data[s] = self.symbol_data[s].\
                reindex(index=comb_index, method='pad').iterrows()
                


    def _get_new_bar(self, symbol):
        """
        Returns the latest bar from the data feed.
        """
#         print("*****data.py: 3. HistoricCSVDataHandler._get_new_bar")
        for b in self.symbol_data[symbol]:
            yield b

    def get_latest_bar(self, symbol):
        """
        Returns the last bar from the latest_symbol list.
        """
#         print("*****data.py: 4. HistoricCSVDataHandler.get_latest_bar")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1]

    def get_latest_bars(self, symbol, N=1):
        """
        Returns the last N bars from the latest_symbol list,
        or N-k if less available.
        """
#         print("*****data.py: 5. HistoricCSVDataHandler.get_latest_bars")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-N:]

    def get_latest_bar_datetime(self, symbol):
        """
        Returns a Python datetime object for the last bar.
        """
#         print("*****data.py: 6. HistoricCSVDataHandler.get_latest_bar_datetime")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return bars_list[-1][0]

    def get_latest_bar_value(self, symbol, val_type):
        """
        Returns one of the Open, High, Low, Close, Volume or OI
        values from the pandas Bar series object.
        """
#         print("*****data.py: 7. HistoricCSVDataHandler.get_latest_bar_value")
        try:
            bars_list = self.latest_symbol_data[symbol]
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return getattr(bars_list[-1][1], val_type)

    def get_latest_bars_values(self, symbol, val_type, N=1):
        """
        Returns the last N bar values from the 
        latest_symbol list, or N-k if less available.
        """
#         print("*****data.py: 8. HistoricCSVDataHandler.get_latest_bars_values")
        try:
            bars_list = self.get_latest_bars(symbol, N)
        except KeyError:
            print("That symbol is not available in the historical data set.")
            raise
        else:
            return np.array([getattr(b[1], val_type) for b in bars_list])

    def update_bars(self):
        """
        Pushes the latest bar to the latest_symbol_data structure
        for all symbols in the symbol list.
        """
#         print("*****data.py: 9. HistoricCSVDataHandler.update_bars")
        for s in self.symbol_list:
            try:
                bar = next(self._get_new_bar(s))
            except StopIteration:
                self.continue_backtest = False
            else:
                if bar is not None:
                    self.latest_symbol_data[s].append(bar)
        self.events.put(MarketEvent())
# Out:
# Executing data.py
# *****data.py: 02 Class: HistoricCSVDataHandler(DataHandler)*****

# %%
# 4. execution.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

# from event import FillEvent, OrderEvent

print("Executing execution.py")
class ExecutionHandler(object):
    """
    The ExecutionHandler abstract class handles the interaction
    between a set of order objects generated by a Portfolio and
    the ultimate set of Fill objects that actually occur in the
    market. 
    The handlers can be used to subclass simulated brokerages
    or live brokerages, with identical interfaces. This allows
    strategies to be backtested in a very similar manner to the
    live trading engine.
    """
#     print ("*****execution.py: 01. Class: ExecutionHandler(object): abstract class*****")
    __metaclass__ = ABCMeta

    @abstractmethod
    def execute_order(self, event):
#         print("*****execution.py: 1. ExecutionHandler.execute_order*****")
        """
        Takes an Order event and executes it, producing
        a Fill event that gets placed onto the Events queue.
        Parameters:
        event - Contains an Event object with order information.
        """
        raise NotImplementedError("Should implement execute_order()")


class SimulatedExecutionHandler(ExecutionHandler):
    
    """
    The simulated execution handler simply converts all order
    objects into their equivalent fill objects automatically
    without latency, slippage or fill-ratio issues.
    This allows a straightforward "first go" test of any strategy,
    before implementation with a more sophisticated execution
    handler.
    """
#     print ("*****execution.py: 02. Class: SimulatedExecutionHandler(ExecutionHandler)*****")
    def __init__(self, events):
        """
        Initialises the handler, setting the event queues
        up internally.
        Parameters:
        events - The Queue of Event objects.
        """
#         print("*****execution.py: 1. SimulatedExecutionHandler.initializing..*****")
        self.events = events

    def execute_order(self, event):
        """
        Simply converts Order objects into Fill objects naively,
        i.e. without any latency, slippage or fill ratio problems.
        Parameters:
        event - Contains an Event object with order information.
        """
#         print("*****execution.py: 2. SimulatedExecutionHandler.execute_order*****")
        if event.type == 'ORDER':
            fill_event = FillEvent(
                datetime.datetime.utcnow(), event.symbol,
                'ARCA', event.quantity, event.direction, None
            )
            self.events.put(fill_event)
# Out:
# Executing execution.py

# %%
# 5. strategy.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

from abc import ABCMeta, abstractmethod
import datetime
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import SignalEvent

print("Executing strategy.py")
class Strategy(object):
#     print("*****strategy.py: 01. Class: Strategy(object): abstract class*****")
    """
    Strategy is an abstract base class providing an interface for
    all subsequent (inherited) strategy handling objects.
    The goal of a (derived) Strategy object is to generate Signal
    objects for particular symbols based on the inputs of Bars 
    (OHLCV) generated by a DataHandler object.
    This is designed to work both with historic and live data as
    the Strategy object is agnostic to where the data came from,
    since it obtains the bar tuples from a queue object.
    """

    __metaclass__ = ABCMeta

    @abstractmethod
    def calculate_signals(self):
#         print("*****strategy.py: 1. Strategy(object).calculate_signals*****")
        """
        Provides the mechanisms to calculate the list of signals.
        """
        raise NotImplementedError("Should implement calculate_signals()")
# Out:
# Executing strategy.py

# %%
# 6. portfolio.py

#!/usr/bin/python
# -*- coding: utf-8 -*-


from __future__ import print_function

import datetime
from math import floor
try:
    import Queue as queue
except ImportError:
    import queue

import numpy as np
import pandas as pd

# from event import FillEvent, OrderEvent
# from performance import create_sharpe_ratio, create_drawdowns


print("Executing portfolio.py")
class Portfolio(object):
    
#     print("*****portfolio.py: 01. Portfolio(object)*****")
    """
    The Portfolio class handles the positions and market
    value of all instruments at a resolution of a "bar",
    i.e. secondly, minutely, 5-min, 30-min, 60 min or EOD.
    The positions DataFrame stores a time-index of the 
    quantity of positions held. 
    The holdings DataFrame stores the cash and total market
    holdings value of each symbol for a particular 
    time-index, as well as the percentage change in 
    portfolio total across bars.
    """

    def __init__(self, bars, events, start_date, initial_capital=100000.0):
#         print("*****portfolio.py: 1. Portfolio.initializing...*****")
        """
        Initialises the portfolio with bars and an event queue. 
        Also includes a starting datetime index and initial capital 
        (USD unless otherwise stated).
        Parameters:
        bars - The DataHandler object with current market data.
        events - The Event Queue object.
        start_date - The start date (bar) of the portfolio.
        initial_capital - The starting capital in USD.
        """
        self.bars = bars
        self.events = events
        self.symbol_list = self.bars.symbol_list
        self.start_date = start_date
        self.initial_capital = initial_capital
        
        self.all_positions = self.construct_all_positions()
        self.current_positions = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        self.all_holdings = self.construct_all_holdings()
        self.current_holdings = self.construct_current_holdings()
        
        # Brad's add on 20191117
#         fill.direction = "None"
#         self.fill_cost = self.update_holdings_from_fill(self, fill)
        
        # =============brad's added on 20191117:===============
        self.len_symbol_list = len(symbol_list)
        
        
        print("Number of assets in the portfolio： ",self.len_symbol_list)
        print("Position Value for each asset: ", self.initial_capital/self.len_symbol_list)

        
    def construct_all_positions(self):
#         print("*****portfolio.py: 2. Portfolio.construct_all_positions*****")
        """
        Constructs the positions list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        return [d]

    def construct_all_holdings(self):
#         print("*****portfolio.py: 3. Portfolio.construct_all_holdings*****")
        """
        Constructs the holdings list using the start_date
        to determine when the time index will begin.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['datetime'] = self.start_date
        d['cash'] = self.initial_capital
        d['commission'] = 0
        d['total'] = self.initial_capital
        return [d]

    def construct_current_holdings(self):
#         print("*****portfolio.py: 4. Portfolio.construct_current_holdings*****")
        """
        This constructs the dictionary which will hold the instantaneous
        value of the portfolio across all symbols.
        """
        d = dict( (k,v) for k, v in [(s, 0.0) for s in self.symbol_list] )
        d['cash'] = self.initial_capital
        d['commission'] = 0
        d['total'] = self.initial_capital
        return d

    def update_timeindex(self, event):
#         print("*****portfolio.py: 5. Portfolio.update_timeindex*****")
        """
        Adds a new record to the positions matrix for the current 
        market data bar. This reflects the PREVIOUS bar, i.e. all
        current market data at this stage is known (OHLCV).
        Makes use of a MarketEvent from the events queue.
        """
        ##print("symbol_list",self.symbol_list)
        latest_datetime = self.bars.get_latest_bar_datetime(self.symbol_list[0])
        #######################
        
        
#         print("latest_datetime:", latest_datetime)
        # Update positions
        # ================
        dp = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dp['datetime'] = latest_datetime

        for s in self.symbol_list:
            dp[s] = self.current_positions[s]

        # Append the current positions
        self.all_positions.append(dp)

        # Update holdings
        # ===============
        dh = dict( (k,v) for k, v in [(s, 0) for s in self.symbol_list] )
        dh['datetime'] = latest_datetime
        dh['cash'] = self.current_holdings['cash']
        dh['commission'] = self.current_holdings['commission']
        dh['total'] = self.current_holdings['cash']

        for s in self.symbol_list:
            # Approximation to the real value
            market_value = self.current_positions[s] * \
                self.bars.get_latest_bar_value(s, price_col)
            dh[s] = market_value
            dh['total'] += market_value

        # Append the current holdings
        self.all_holdings.append(dh)

    # ======================
    # FILL/POSITION HANDLING
    # ======================

    def update_positions_from_fill(self, fill):
#         print("*****portfolio.py: 6. Portfolio.update_positions_from_fill*****")
        """
        Takes a Fill object and updates the position matrix to
        reflect the new position.
        Parameters:
        fill - The Fill object to update the positions with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update positions list with new quantities
        self.current_positions[fill.symbol] += fill_dir*fill.quantity

    def update_holdings_from_fill(self, fill):
#         print("*****portfolio.py: 7. Portfolio.update_holdings_from_fill*****")
        """
        Takes a Fill object and updates the holdings matrix to
        reflect the holdings value.
        Parameters:
        fill - The Fill object to update the holdings with.
        """
        # Check whether the fill is a buy or sell
        fill_dir = 0
        if fill.direction == 'BUY':
            fill_dir = 1
        if fill.direction == 'SELL':
            fill_dir = -1

        # Update holdings list with new quantities
        fill_cost = self.bars.get_latest_bar_value(
            fill.symbol, price_col
        )
        cost = fill_dir * fill_cost * fill.quantity
        self.current_holdings[fill.symbol] += cost
        self.current_holdings['commission'] += fill.commission
        self.current_holdings['cash'] -= (cost + fill.commission)
        self.current_holdings['total'] -= (cost + fill.commission)
        # Brad's add on 20191117
        return fill_cost

    def update_fill(self, event):
#         print("*****portfolio.py: 8. Portfolio.update_fill*****")
        """
        Updates the portfolio current positions and holdings 
        from a FillEvent.
        """
        if event.type == 'FILL':
            self.update_positions_from_fill(event)
            self.update_holdings_from_fill(event)

    def generate_naive_order(self, signal):
#         print("*****portfolio.py: 9. Portfolio.generate_naive_order*****")
        """
        Simply files an Order object as a constant quantity
        sizing of the signal object, without risk management or
        position sizing considerations.
        Parameters:
        signal - The tuple containing Signal information.
        """
        order = None

        symbol = signal.symbol
        direction = signal.signal_type
        strength = signal.strength
        # ================ Brad's change on 20191117 =================
        mkt_quantity = qty
        symbol_value = self.bars.get_latest_bar_value(symbol, price_col)
#         mkt_quantity = int(self.initial_capital/self.len_symbol_list/symbol_value)
        print("Asset: ", symbol, "symbol_value: ",symbol_value,  "mkt_quantity: ", mkt_quantity)
        cur_quantity = self.current_positions[symbol]
        order_type = 'MKT'

        
        if direction == 'LONG' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'BUY')
        if direction == 'SHORT' and cur_quantity == 0:
            order = OrderEvent(symbol, order_type, mkt_quantity, 'SELL')   
    
#         if direction == 'LONG' and cur_quantity < 0:
#             order = OrderEvent(symbol, order_type, 2*mkt_quantity, 'BUY')
#         if dirction == 'SHORT' and cur_quantity > 0:
#             order = OrderEvent(symbol, order_type, 2*mkt_quantity, 'SELL')
    
        if direction == 'EXIT' and cur_quantity > 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'SELL')
        if direction == 'EXIT' and cur_quantity < 0:
            order = OrderEvent(symbol, order_type, abs(cur_quantity), 'BUY')
        return order

    def update_signal(self, event):
#         print("*****portfolio.py: 10. Portfolio.update_signal*****")
        """
        Acts on a SignalEvent to generate new orders 
        based on the portfolio logic.
        """
        if event.type == 'SIGNAL':
            order_event = self.generate_naive_order(event)
            self.events.put(order_event)

    # ========================
    # POST-BACKTEST STATISTICS
    # ========================

    def create_equity_curve_dataframe(self):
#         print("*****portfolio.py: 11. Portfolio.create_equity_curve_dataframe*****")
        """
        Creates a pandas DataFrame from the all_holdings
        list of dictionaries.
        """
        curve = pd.DataFrame(self.all_holdings)
        curve.set_index('datetime', inplace=True)
        curve['returns'] = curve['total'].pct_change()
        curve['equity_curve'] = (1.0+curve['returns']).cumprod()
        self.equity_curve = curve

    def output_summary_stats(self):
#         print("*****portfolio.py: 12. Portfolio.output_summary_stats*****")
        """
        Creates a list of summary statistics for the portfolio.
        """
        total_return = self.equity_curve['equity_curve'][-1]
        returns = self.equity_curve['returns']
        pnl = self.equity_curve['equity_curve']

        sharpe_ratio = create_sharpe_ratio(returns, periods=252*60*6.5)
        drawdown, max_dd, dd_duration = create_drawdowns(pnl)
        self.equity_curve['drawdown'] = drawdown

        stats = [("Total Return", "%0.2f%%" % ((total_return - 1.0) * 100.0)),
                 ("Sharpe Ratio", "%0.2f" % sharpe_ratio),
                 ("Max Drawdown", "%0.2f%%" % (max_dd * 100.0)),
                 ("Drawdown Duration", "%d" % dd_duration)]

        self.equity_curve.to_csv(ticker+"_performance"+".csv")
#         return self.equity_curve
#         print(stats)


class Visualization(Portfolio):
    def output_summary_stats(self):
#         print("*****portfolio.py: 12. Portfolio.output_summary_stats*****")
        """
        Creates a list of summary statistics for the portfolio.
        """
        total_return = self.equity_curve['equity_curve'][-1]
        returns = self.equity_curve['returns']
        pnl = self.equity_curve['equity_curve']

        sharpe_ratio = create_sharpe_ratio(returns, periods=252*60*6.5)
        drawdown, max_dd, dd_duration = create_drawdowns(pnl)
        self.equity_curve['drawdown'] = drawdown
        self.equity_curve['drawdown'].plot()

#         stats = [("Total Return", "%0.2f%%" % ((total_return - 1.0) * 100.0)),
#                  ("Sharpe Ratio", "%0.2f" % sharpe_ratio),
#                  ("Max Drawdown", "%0.2f%%" % (max_dd * 100.0)),
#                  ("Drawdown Duration", "%d" % dd_duration)]

#     def __init__(self, bars, events, start_date, initial_capital=100000.0):
#         self.stats_to_plot = super().output_summary_stats()

#     def plot_cash(self):
#         self.stats_to_plot['cash'].plot()

#     # Added by Brad on 20191007:
#     def draw_summary_plots(self):
#         print("*****portfolio.py: 13. Portfolio.draw_summary_plots*****")
#         self.equity_curve['equity_curve'].plot(figsize = (18,6))
# Out:
# Executing portfolio.py

# %%
# 7. performance.py

#!/usr/bin/python
# -*- coding: utf-8 -*-

from __future__ import print_function

import numpy as np
import pandas as pd

print("Executing performance.py")
def create_sharpe_ratio(returns, periods=252):
    print("*****performance.py: 1. create_sharpe_ratio*****")
    """
    Create the Sharpe ratio for the strategy, based on a 
    benchmark of zero (i.e. no risk-free rate information).
    Parameters:
    returns - A pandas Series representing period percentage returns.
    periods - Daily (252), Hourly (252*6.5), Minutely(252*6.5*60) etc.
    """
    return np.sqrt(periods) * (np.mean(returns)) / np.std(returns)


def create_drawdowns(pnl):
    print("*****performance.py: 2. create_drawdowns*****")
    """
    Calculate the largest peak-to-trough drawdown of the PnL curve
    as well as the duration of the drawdown. Requires that the 
    pnl_returns is a pandas Series.
    Parameters:
    pnl - A pandas Series representing period percentage returns.
    Returns:
    drawdown, duration - Highest peak-to-trough drawdown and duration.
    """

    # Calculate the cumulative returns curve 
    # and set up the High Water Mark
    hwm = [0]

    # Create the drawdown and duration series
    idx = pnl.index
    drawdown = pd.Series(index = idx)
    duration = pd.Series(index = idx)

    # Loop over the index range
    for t in range(1, len(idx)):
        hwm.append(max(hwm[t-1], pnl[t]))
        drawdown[t]= (hwm[t]-pnl[t])
        duration[t]= (0 if drawdown[t] == 0 else duration[t-1]+1)
    return drawdown, drawdown.max(), duration.max()
# Out:
# Executing performance.py

# %%
# mac.py
print("Executing mac.py")
class MovingAverageCrossStrategy(Strategy):
    print("*****mac.py: 01. Class: MovingAverageCrossStrategy(Strategy)*****")
    """
    Carries out a basic Moving Average Crossover strategy with a
    short/long simple weighted moving average. Default short/long
    windows are 12/26 periods respectively.
    """

    def __init__(self, bars, events, short_window=12, long_window=26):
        print("*****mac.py: 1. MovingAverageCrossStrategy.initializing..*****")
        """
        Initialises the buy and hold strategy.

        Parameters:
        bars - The DataHandler object that provides bar information
        events - The Event Queue object.
        short_window - The short moving average lookback.
        long_window - The long moving average lookback.
        """
        self.bars = bars
        self.symbol_list = self.bars.symbol_list
        self.events = events
        self.short_window = short_window
        self.long_window = long_window

        # Set to True if a symbol is in the market
        self.bought = self._calculate_initial_bought()

    def _calculate_initial_bought(self):
        print("*****mac.py: 2. MovingAverageCrossStrategy._calculate_initial_bought*****")
        """
        Adds keys to the bought dictionary for all symbols
        and sets them to 'OUT'.
        """
        bought = {}
        for s in self.symbol_list:
            bought[s] = 'OUT'
        return bought
    
    # added on 20200425 by Brad
    def _calculate_initial_sold(self):
        print("*****mac.py: 2. MovingAverageCrossStrategy._calculate_initial_sold*****")
        """
        Adds keys to the sold dictionary for all symbols
        and sets them to 'OUT'.
        """
    
        sold = {}
        for s in self.symbol_list:
            sold[s] = 'OUT'
        return sold

    def calculate_signals(self, event):
        print("*****mac.py: 3. MovingAverageCrossStrategy.calculate_signals*****")
        """
        Generates a new set of signals based on the MAC
        SMA with the short window crossing the long window
        meaning a long entry and vice versa for a short entry.    

        Parameters
        event - A MarketEvent object. 
        """
        if event.type == 'MARKET':
            for symbol in self.symbol_list:
                bars = self.bars.get_latest_bars_values(symbol, price_col, N=self.long_window)

                if bars is not None and bars != []:
                    short_sma = np.mean(bars[-self.short_window:])
                    long_sma = np.mean(bars[-self.long_window:])

                    dt = self.bars.get_latest_bar_datetime(symbol)
                    sig_dir = ""
                    strength = 1.0
                    strategy_id = 1

                    if short_sma > long_sma and self.bought[symbol] == "OUT":
                        sig_dir = 'LONG'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'LONG'

                    elif short_sma < long_sma and self.bought[symbol] == "LONG":
                        sig_dir = 'EXIT'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'OUT'
# Out:
# Executing mac.py
# *****mac.py: 01. Class: MovingAverageCrossStrategy(Strategy)*****

# %%
class MovingAverageConvergenceDivergence(Strategy):
    
    def __init__(self, bars, events, short_window=12, long_window=26):
        self.bars = bars
        self.symbol_list = self.bars.symbol_list
        self.events = events
        self.short_window = short_window
        self.long_window = long_window

        # Set to True if a symbol is in the market
        self.bought = self._calculate_initial_bought()
        # Set to True if a symbol is in the market
        self.sold = self._calculate_initial_sold()

    def _calculate_initial_bought(self):
        """
        Adds keys to the bought dictionary for all symbols
        and sets them to 'OUT'.
        """
        bought = {}
        for s in self.symbol_list:
            bought[s] = 'OUT'
        return bought
    
    
    # added on 20200425 by Brad
    def _calculate_initial_sold(self):
        print("*****mac.py: 2. MovingAverageCrossStrategy._calculate_initial_sold*****")
        """
        Adds keys to the sold dictionary for all symbols
        and sets them to 'OUT'.
        """
    
        sold = {}
        for s in self.symbol_list:
            sold[s] = 'OUT'
        return sold
    

    def calculate_signals(self, event):
        """
        Generates a new set of signals based on the MAC
        SMA with the short window crossing the long window
        meaning a long entry and vice versa for a short entry.
        Parameters
        event - A MarketEvent object.
        """
        if event.type == 'MARKET':
            for symbol in self.symbol_list:
                bars = self.bars.get_latest_bars_values(symbol, price_col, N=self.long_window)
                if bars is not None and bars != []:
                    exp1 = pd.Series(bars).ewm(span=12, adjust=False).mean()
                    exp2 = pd.Series(bars).ewm(span=26, adjust=False).mean()
                    macd = exp1 - exp2
                    exp3 = macd.ewm(span=9, adjust=False).mean()
                    dt = self.bars.get_latest_bar_datetime(symbol)
                    sig_dir = ""
                    strength = 1.0
                    strategy_id = 1
                    
#                     # if MACD signal is positive and there's no long position, 
#                     if macd.iloc[-1] > exp3.iloc[-1] and self.bought[symbol] == "OUT":
#                         sig_dir = 'LONG'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.bought[symbol] = 'LONG'
                        
#                     # if MACD signal is positive and there's short position,
#                     if macd.iloc[-1] > exp3.iloc[-1] and self.sold[symbol] == "SHORT":
#                         sig_dir = 'LONG'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.bought[symbol] = 'LONG'
#                         self.sold[symbol] = 'OUT'
                        
#                     # if MACD signal is negative and there's no short position
#                     elif macd.iloc[-1] < exp3.iloc[-1] and self.sold[symbol] == "OUT":
#                         sig_dir = 'SHORT'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.sold[symbol] = 'SHORT'
                        
#                     # if MACD signal is negative and there's long position
#                     elif macd.iloc[-1] < exp3.iloc[-1] and self.bought[symbol] == "LONG":
#                         sig_dir = 'SHORT'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.sold[symbol] = 'SHORT'
#                         self.bought[symbol] = 'OUT'




#                     if macd.iloc[-1] > exp3.iloc[-1] and self.bought[symbol] == "OUT":
#                         sig_dir = 'LONG'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.bought[symbol] = 'LONG'
                        
#                     if macd.iloc[-1] < exp3.iloc[-1] and self.bought[symbol] == "OUT":
#                         sig_dir = 'SHORT'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.bought[symbol] = 'SHORT'
                        
                        
#                     if macd.iloc[-1] > exp3.iloc[-1] and self.bought[symbol] == "SHORT":
#                         sig_dir = 'EXIT'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
# #                         self.bought[symbol] = 'OUT'
                        
#                         sig_dir = 'LONG'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.bought[symbol] = 'LONG'
                    
            
#                     if macd.iloc[-1] < exp3.iloc[-1] and self.bought[symbol] == "LONG":
#                         sig_dir = 'EXIT'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
# #                         self.bought[symbol] = 'OUT'
                        
#                         sig_dir = 'SHORT'
#                         signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
#                         self.events.put(signal)
#                         self.bought[symbol] = 'SHORT'


                    if macd.iloc[-1] > exp3.iloc[-1] and self.bought[symbol] == "OUT":
                        sig_dir = 'LONG'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'LONG'

                    elif macd.iloc[-1] < exp3.iloc[-1] and self.bought[symbol] == "LONG":
                        sig_dir = 'EXIT'
                        signal = SignalEvent(strategy_id, symbol, dt, sig_dir, strength)
                        self.events.put(signal)
                        self.bought[symbol] = 'OUT'

# %%
class Visualization(object):
    def __init__(self, bt_csv_dir, start_date_str):
        self.equity_curve = pd.read_csv(bt_csv_dir+"equity.csv")
        self.equity_curve.drop_duplicates("datetime", inplace = True)
        self.equity_curve =self.equity_curve[self.equity_curve['datetime']>start_date_str]
        self.equity_curve.index = self.equity_curve['datetime']
        self.equity_curve = self.equity_curve[self.equity_curve['total'].map(lambda x: str(x)!="nan")]
        self.equity_curve.drop(['datetime'], axis = 1, inplace=True)
        self.plot_size = [18, 6]
        
    def plot_commissions(self):
        self.equity_curve['commission'].plot(figsize = self.plot_size)
        
    def plot_cash(self):
        self.equity_curve['cash'].plot(figsize = self.plot_size)
        
    def plot_total(self):
        self.equity_curve['total'].plot(figsize = self.plot_size)
        
    def plot_returns(self):
        self.equity_curve['returns'].plot(figsize = self.plot_size)
        
    def plot_equity_curve(self):
        self.equity_curve['equity_curve'].plot(figsize = self.plot_size)
        
    def plot_drawdown(self):
        self.equity_curve['drawdown'].plot(figsize = self.plot_size)
        
    def return_equity_df(self):
        return self.equity_curve

# %%
# # Hansen's version
# def performance(data):
#     data['daily_PL'] = data['total']-data['total'].shift(1)

#     trade = False
#     profits = []
#     total_profit_per_trade = 0

#     for i in range(len(data)): 
#         if data.iloc[i]['market_value'] == 0.0 and data.iloc[i]['returns'] == 0.0 and trade:
#             trade = False
        
#             profits.append(total_profit_per_trade)
#             total_profit_per_trade = 0

#         if trade:
#             total_profit_per_trade += data.iloc[i]['daily_PL']

#         if data.iloc[i]['market_value'] != 0.0 and not trade:
#             trade = True
#             total_profit_per_trade += data.iloc[i]['daily_PL']

#     win_trade = list(filter(lambda x: x >0, profits))
#     loss_trade = list(filter(lambda x: x <0, profits))
#     num_win_trade = len(win_trade)
#     num_total_trade = len(profits)
#     win_rate = num_win_trade/num_total_trade*100
#     mean_win_loss_ratio = np.mean(win_trade)/(-np.mean(loss_trade))
#     bt_score = (win_rate/100*mean_win_loss_ratio-(1-win_rate/100))
#     print('win %:', num_win_trade/num_total_trade*100)
#     print('PL Ratio:', np.mean(win_trade)/(-np.mean(loss_trade)))
#     print('bt_score:', bt_score)
#     return win_rate, mean_win_loss_ratio, bt_score, profits

# %%
# Brad' revised version:

def performance(data):
    commissions = 5 # in USD or RMB
    # Create daily PnL
    data['daily_PL'] = data['total']-data['total'].shift(1)
    trade = False
    profits = []
    total_profit_per_trade = 0
    single_stats = {}
    for i in range(len(data)): 
        
        
        # 1.1 open the position:
        if i > 1 and data.iloc[i-1]['market_value'] == 0 and data.iloc[i]['market_value'] != 0:
            print("-------------------")
            print("Opened the position: ", data.iloc[i]['datetime'])
            total_profit_per_trade += data.iloc[i]['daily_PL']-commissions
            
        # 1.2 open the position (if there's no data before):
        if i == 0 and data.iloc[i]['market_value'] != 0:
            print("No data before, opened the position: ", data.iloc[i]['datetime'])
            total_profit_per_trade += data.iloc[i]['daily_PL']-commissions
            
        # 2. holding the position:
        if i > 1 and data.iloc[i-1]['market_value'] != 0 and data.iloc[i]['market_value'] != 0:
            print("Holding the position: ", data.iloc[i]['datetime'])
            total_profit_per_trade += data.iloc[i]['daily_PL']
            
            
        # 3. close the position:
        if i > 1 and data.iloc[i-1]['market_value'] !=0 and data.iloc[i]['market_value'] == 0:
            print("Closed the position: ", data.iloc[i]['datetime'])
            profits.append(total_profit_per_trade)
            # The most recent trade is over, reset total_profit_per_trade
            print("This trade's pnl:", total_profit_per_trade)
            total_profit_per_trade = 0
            print("-------------------")
        
            
        # 4. if the position is empty 
        if data.iloc[i]['market_value'] == 0:
            print("Position is empty: ", data.iloc[i]['datetime'])
            

    win_trade = list(filter(lambda x: x >0, profits))
    loss_trade = list(filter(lambda x: x <0, profits))
    num_win_trade = len(win_trade)
    num_total_trade = len(profits)
    win_rate = num_win_trade/num_total_trade*100
    mean_win_loss_ratio = np.mean(win_trade)/(-np.mean(loss_trade))
    bt_score = (win_rate/100*mean_win_loss_ratio-(1-win_rate/100))
    total_commission = data['commission'].values[-1]
    gross_profit = sum(profits)+total_commission
    net_profit = sum(profits)
    commission_cost_rate = total_commission/gross_profit
    
    
    print('total_commission: ', total_commission)
    print('gross_profit: ', round(gross_profit,2))
    print('net_profit: ', round(net_profit,2))
    print('commission_impact: {}%'.format(abs(round(commission_cost_rate*100, 2))))
    print('win %:', round(num_win_trade/num_total_trade*100,2))
    print('PL Ratio:', round(np.mean(win_trade)/(-np.mean(loss_trade)),2))
    
    single_stats['total_commission'] = total_commission
    single_stats['gross_profit'] = round(gross_profit,2)
    single_stats['net_profit'] = round(net_profit,2)
    single_stats['commission_impact'] = str(abs(round(commission_cost_rate*100, 2)))+"%"
    single_stats['win %'] = round(num_win_trade/num_total_trade*100,2)
    single_stats['PL Ratio'] = round(np.mean(win_trade)/(-np.mean(loss_trade)),2)
    single_stats['overall_score'] = round(win_rate/100*mean_win_loss_ratio-(1-win_rate/100),2)
    return single_stats

# %%
5/0.00025
# Out:
# 20000.0

# %%
symbol_list = [
#     "DBC",
#     "DBC",#overall score: -0.17 收益率多样化商品指数
#     "TLT",#overall score: 0.04 美国国债20年以上
#     "IEF",#overall score: 0.09 美国国债7-10年
#     "GLD",# overall score:0.13 
#     "SPY"#overall score: 0.13 
#     "IEI"#overall score: 0.26 美国国债2-7年
]
ticker_performances = {}

if __name__ == "__main__":
    for ticker in symbol_list:
    # csv_dir = REPLACE_WITH_YOUR_CSV_DIR_HERE
        equity_folder = "./"
        csv_dir = "/Users/miaoyuesun/Code_Workspace/brad_public_workspace_mac/data/US_database/"
    #     symbol_list = [

    # # ==============ETF================
    # #         "518880", # 黄金ETF
    # #         "513050",# 中概互联网
    # #         "513100",# 纳指ETF
    # #         "159920",# 恒生ETF
    # #         "510900",# 【H股ETF：弃，MACD不赚钱】
    # #         "512010",#医药ETF，
    # # ==============股票================
    # #         "002559.SZ",
    # #         "002638.SZ",
    # #         "601899.SH",#紫金矿业
    # #         "600208.SH",#新湖中宝、所属板块：参股券商
    # #         "000069.SZ",#华侨城A
    # #         "002524.SZ",#光正集团
    # #         "600712.SH",#南宁百货
    # #         "002610.SZ",#爱康科技
    # #         "601777.SH",#【力帆股份：基本面弱，暂弃】
    #         "002094.SZ",#青岛金王
    # #         "600467.SH"#【好当家：股价涨太高，暂时弃】

    #     ]
        data_cols = ['Date', 'Open', 'High','Low', 'Close', 'Adj Close' ,'Volume','Ticker'] #for ETFs
#         data_cols = ['ts_code','trade_date','open','high','low','close','pre_close','change','pct_chg','vol','amount'] #for stocks
        commissions = 0 # RMB/USD per trade
        initial_capital = 3000
        start_date = datetime.datetime(1991,1,1,0,0,0)
        start_date_str = str(start_date)
        heartbeat = 0.0
        date_col = "Date"
        price_col = "Adj Close"
        qty = 40
        backtest = Backtest(csv_dir, 
                            [ticker], 
                            initial_capital, 
                            heartbeat,
                            start_date,
                            HistoricCSVDataHandler, 
                            SimulatedExecutionHandler, 
                            Portfolio, 
    #                         MovingAverageCrossStrategy,
                           MovingAverageConvergenceDivergence)

        backtest.simulate_trading()
        df_equity = pd.read_csv(ticker+"_performance"+".csv")
        df_equity.drop_duplicates("datetime", inplace = True)
        df_equity =df_equity[df_equity['datetime']>start_date_str]
        df_equity.index = df_equity['datetime']
        df_equity = df_equity[df_equity['total'].map(lambda x: str(x)!="nan")]
        df_equity.columns = ['datetime', 'market_value', 'cash', 'commission', 'total', 'returns',
        'equity_curve', 'drawdown']
        df_equity_copy = df_equity.copy()
        data = df_equity_copy
#         win_rate, mean_win_loss_ratio, bt_score, profits = performance(data)
        single_stats = performance(data)
#         print("TICKER: ", ticker)
        ticker_performances[ticker] = single_stats
# Out:
# *****mac.py: 2. MovingAverageCrossStrategy._calculate_initial_sold*****
# Number of assets in the portfolio：  1
# Position Value for each asset:  3000.0
# Asset:  IEI symbol_value:  77.42838287353516 mkt_quantity:  40
# Asset:  IEI symbol_value:  77.35089111328125 mkt_quantity:  40
# Asset:  IEI symbol_value:  77.34849548339844 mkt_quantity:  40
# Asset:  IEI symbol_value:  78.66114044189453 mkt_quantity:  40
# Asset:  IEI symbol_value:  78.82054138183594 mkt_quantity:  40
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:51: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:51: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# Asset:  IEI symbol_value:  78.86043548583984 mkt_quantity:  40
# Asset:  IEI symbol_value:  78.11579895019531 mkt_quantity:  40
# Asset:  IEI symbol_value:  79.84452819824219 mkt_quantity:  40
# Asset:  IEI symbol_value:  79.98751068115234 mkt_quantity:  40
# Asset:  IEI symbol_value:  81.57655334472656 mkt_quantity:  40
# Asset:  IEI symbol_value:  81.64031982421875 mkt_quantity:  40
# Asset:  IEI symbol_value:  81.04240417480469 mkt_quantity:  40
# Asset:  IEI symbol_value:  81.7139663696289 mkt_quantity:  40
# Asset:  IEI symbol_value:  81.4098892211914 mkt_quantity:  40
# Asset:  IEI symbol_value:  81.65790557861328 mkt_quantity:  40
# Asset:  IEI symbol_value:  84.67671966552734 mkt_quantity:  40
# Asset:  IEI symbol_value:  85.26976776123047 mkt_quantity:  40
# Asset:  IEI symbol_value:  87.46780395507812 mkt_quantity:  40
# Asset:  IEI symbol_value:  88.26338958740234 mkt_quantity:  40
# Asset:  IEI symbol_value:  87.65576171875 mkt_quantity:  40
# Asset:  IEI symbol_value:  88.23096466064453 mkt_quantity:  40
# Asset:  IEI symbol_value:  88.04463195800781 mkt_quantity:  40
# Asset:  IEI symbol_value:  88.39302062988281 mkt_quantity:  40
# Asset:  IEI symbol_value:  89.27066040039062 mkt_quantity:  40
# Asset:  IEI symbol_value:  88.00293731689453 mkt_quantity:  40
# Asset:  IEI symbol_value:  87.13007354736328 mkt_quantity:  40
# Asset:  IEI symbol_value:  87.58352661132812 mkt_quantity:  40
# Asset:  IEI symbol_value:  86.87191009521484 mkt_quantity:  40
# Asset:  IEI symbol_value:  86.51201629638672 mkt_quantity:  40
# Asset:  IEI symbol_value:  87.17169952392578 mkt_quantity:  40
# Asset:  IEI symbol_value:  88.04781341552734 mkt_quantity:  40
# Asset:  IEI symbol_value:  89.26995849609375 mkt_quantity:  40
# Asset:  IEI symbol_value:  90.80140686035156 mkt_quantity:  40
# Asset:  IEI symbol_value:  89.22348022460938 mkt_quantity:  40
# Asset:  IEI symbol_value:  90.93363189697266 mkt_quantity:  40
# Asset:  IEI symbol_value:  90.677490234375 mkt_quantity:  40
# Asset:  IEI symbol_value:  91.48831176757812 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.35733795166016 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.56778717041016 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.5261688232422 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.8175048828125 mkt_quantity:  40
# Asset:  IEI symbol_value:  95.8852767944336 mkt_quantity:  40
# Asset:  IEI symbol_value:  95.42610168457031 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.0245590209961 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.96509552001952 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.43017578125 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.00169372558594 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.97644805908205 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.8418197631836 mkt_quantity:  40
# Asset:  IEI symbol_value:  93.96080780029295 mkt_quantity:  40
# Asset:  IEI symbol_value:  92.50667572021484 mkt_quantity:  40
# Asset:  IEI symbol_value:  93.22228240966795 mkt_quantity:  40
# Asset:  IEI symbol_value:  93.03579711914062 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.69731903076172 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.87490844726562 mkt_quantity:  40
# Asset:  IEI symbol_value:  95.34635162353516 mkt_quantity:  40
# Asset:  IEI symbol_value:  95.23175811767578 mkt_quantity:  40
# Asset:  IEI symbol_value:  95.9621353149414 mkt_quantity:  40
# Asset:  IEI symbol_value:  94.89456939697266 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.06598663330078 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.54759216308594 mkt_quantity:  40
# Asset:  IEI symbol_value:  96.2494659423828 mkt_quantity:  40
# Asset:  IEI symbol_value:  95.73240661621094 mkt_quantity:  40
# Asset:  IEI symbol_value:  98.1502456665039 mkt_quantity:  40
# Asset:  IEI symbol_value:  99.0180206298828 mkt_quantity:  40
# Asset:  IEI symbol_value:  98.40251922607422 mkt_quantity:  40
# Asset:  IEI symbol_value:  99.0526885986328 mkt_quantity:  40
# Asset:  IEI symbol_value:  99.5217514038086 mkt_quantity:  40
# Asset:  IEI symbol_value:  100.18180847167969 mkt_quantity:  40
# Asset:  IEI symbol_value:  100.08625030517578 mkt_quantity:  40
# Asset:  IEI symbol_value:  100.7201919555664 mkt_quantity:  40
# Asset:  IEI symbol_value:  101.818359375 mkt_quantity:  40
# Asset:  IEI symbol_value:  102.20496368408205 mkt_quantity:  40
# Asset:  IEI symbol_value:  103.373046875 mkt_quantity:  40
# Asset:  IEI symbol_value:  104.03076171875 mkt_quantity:  40
# Asset:  IEI symbol_value:  103.4976043701172 mkt_quantity:  40
# Asset:  IEI symbol_value:  100.51628875732422 mkt_quantity:  40
# Asset:  IEI symbol_value:  100.74424743652344 mkt_quantity:  40
# Asset:  IEI symbol_value:  101.05990600585938 mkt_quantity:  40
# Asset:  IEI symbol_value:  100.8147430419922 mkt_quantity:  40
# Asset:  IEI symbol_value:  99.92774963378906 mkt_quantity:  40
# Asset:  IEI symbol_value:  101.17295837402344 mkt_quantity:  40
# Asset:  IEI symbol_value:  100.67021942138672 mkt_quantity:  40
# Asset:  IEI symbol_value:  104.3424835205078 mkt_quantity:  40
# Asset:  IEI symbol_value:  104.44857025146484 mkt_quantity:  40
# Asset:  IEI symbol_value:  104.1391372680664 mkt_quantity:  40
# Asset:  IEI symbol_value:  104.80682373046876 mkt_quantity:  40
# Asset:  IEI symbol_value:  107.13630676269531 mkt_quantity:  40
# Asset:  IEI symbol_value:  107.93861389160156 mkt_quantity:  40
# Asset:  IEI symbol_value:  107.814208984375 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.23165893554688 mkt_quantity:  40
# Asset:  IEI symbol_value:  107.78760528564452 mkt_quantity:  40
# Asset:  IEI symbol_value:  107.23180389404295 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.16930389404295 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.39187622070312 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.31178283691406 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.43675994873048 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.4991226196289 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.8749771118164 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.55381774902344 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.74119567871094 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.5181655883789 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.01768493652344 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.03144073486328 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.0852279663086 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.79025268554688 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.22705841064452 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.28551483154295 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.4376220703125 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.83242797851562 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.28913116455078 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.13304901123048 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.3212432861328 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.01651000976562 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.3212432861328 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.24057006835938 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.42628479003906 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.7042999267578 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.59730529785156 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.83766174316406 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.09812927246094 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.95702362060548 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.6785125732422 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.9031219482422 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.28052520751952 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.28776550292969 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.3596649169922 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.11695098876952 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.6161117553711 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.44524383544922 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.62164306640624 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.3156509399414 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.5406494140625 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.47762298583984 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.51365661621094 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.65474700927734 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.04186248779295 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.62374114990234 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.81293487548828 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.56234741210938 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.34382629394531 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.36093139648438 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.92996215820312 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.13746643066406 mkt_quantity:  40
# Asset:  IEI symbol_value:  107.9608154296875 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.3926010131836 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.84468841552734 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.84986114501952 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.97652435302734 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.83415985107422 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.07915496826172 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.67129516601562 mkt_quantity:  40
# Asset:  IEI symbol_value:  108.80726623535156 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.88372802734376 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.34637451171876 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.06765747070312 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.3581771850586 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.56828308105469 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.80723571777344 mkt_quantity:  40
# Asset:  IEI symbol_value:  109.661865234375 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.25276184082031 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.81924438476562 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.53692626953124 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.63956451416016 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.79454040527344 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.62133026123048 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.9312515258789 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.5848617553711 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.96742248535156 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.09514617919922 mkt_quantity:  40
# Asset:  IEI symbol_value:  110.7659912109375 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.3362274169922 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.97689056396484 mkt_quantity:  40
# Asset:  IEI symbol_value:  111.87527465820312 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.78276824951172 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.00362396240234 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.4847640991211 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.30288696289062 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.54043579101562 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.7856216430664 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.98793029785156 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.35345458984376 mkt_quantity:  40
# Asset:  IEI symbol_value:  112.8408432006836 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.14851379394531 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.64567565917969 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.60884857177734 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.66561126708984 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.28771209716795 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.49048614501952 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.00818634033205 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.4142074584961 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.22479248046876 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.75135803222656 mkt_quantity:  40
# Asset:  IEI symbol_value:  113.84793853759766 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.04216766357422 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.15311431884766 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.495361328125 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.18087768554688 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.63922119140624 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.37997436523438 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.96334838867188 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.55891418457031 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.99463653564452 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.42914581298828 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.24823760986328 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.20622253417969 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.35335540771484 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.95704650878906 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.6892318725586 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.55188751220705 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.4942626953125 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.89611053466795 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.8315887451172 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.8596420288086 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.74849700927734 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.80799865722656 mkt_quantity:  40
# Asset:  IEI symbol_value:  119.03727722167969 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.718505859375 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.79678344726562 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.3087158203125 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.3462371826172 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.36460876464844 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.2424774169922 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.85725402832031 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.1251449584961 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.15636444091795 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.59610748291016 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.41917419433594 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.02666473388672 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.56391143798828 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.10244750976562 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.46077728271484 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.02693939208984 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.59422302246094 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.45254516601562 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.73213958740234 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.47793579101562 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.50065612792969 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.69973754882812 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.4722137451172 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.3510971069336 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.16967010498048 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.51107788085938 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.21565246582031 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.32050323486328 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.10579681396484 mkt_quantity:  40
# Asset:  IEI symbol_value:  117.1739273071289 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.95418548583984 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.87718963623048 mkt_quantity:  40
# Asset:  IEI symbol_value:  116.56146240234376 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.1795425415039 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.3553237915039 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.48004150390624 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.57384490966795 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.94084167480469 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.32496643066406 mkt_quantity:  40
# Asset:  IEI symbol_value:  114.78688049316406 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.0995864868164 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.51410675048828 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.67122650146484 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.8160629272461 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.67122650146484 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.59537506103516 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.87586975097656 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.36580657958984 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.00569915771484 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.180419921875 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.23729705810548 mkt_quantity:  40
# Asset:  IEI symbol_value:  115.72351837158205 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.2742919921875 mkt_quantity:  40
# Asset:  IEI symbol_value:  118.7524642944336 mkt_quantity:  40
# Asset:  IEI symbol_value:  119.16246795654295 mkt_quantity:  40
# Asset:  IEI symbol_value:  119.28844451904295 mkt_quantity:  40
# Asset:  IEI symbol_value:  120.1974868774414 mkt_quantity:  40
# Asset:  IEI symbol_value:  120.31523895263672 mkt_quantity:  40
# Asset:  IEI symbol_value:  123.59383392333984 mkt_quantity:  40
# Asset:  IEI symbol_value:  123.85974884033205 mkt_quantity:  40
# Asset:  IEI symbol_value:  123.7541961669922 mkt_quantity:  40
# Asset:  IEI symbol_value:  123.70486450195312 mkt_quantity:  40
# Asset:  IEI symbol_value:  126.23395538330078 mkt_quantity:  40
# Asset:  IEI symbol_value:  126.73385620117188 mkt_quantity:  40
# Asset:  IEI symbol_value:  126.0606918334961 mkt_quantity:  40
# Asset:  IEI symbol_value:  125.66471862792969 mkt_quantity:  40
# Asset:  IEI symbol_value:  125.57569122314452 mkt_quantity:  40
# Asset:  IEI symbol_value:  125.72515106201172 mkt_quantity:  40
# Asset:  IEI symbol_value:  124.6924285888672 mkt_quantity:  40
# Asset:  IEI symbol_value:  125.35772705078124 mkt_quantity:  40
# Asset:  IEI symbol_value:  125.2303466796875 mkt_quantity:  40
# Asset:  IEI symbol_value:  125.3373794555664 mkt_quantity:  40
# Asset:  IEI symbol_value:  126.8988800048828 mkt_quantity:  40
# Asset:  IEI symbol_value:  127.6668701171875 mkt_quantity:  40
# Asset:  IEI symbol_value:  129.95191955566406 mkt_quantity:  40
# Asset:  IEI symbol_value:  132.39894104003906 mkt_quantity:  40
# Asset:  IEI symbol_value:  133.41999816894528 mkt_quantity:  40
# Asset:  IEI symbol_value:  133.52000427246094 mkt_quantity:  40
# Asset:  IEI symbol_value:  133.33000183105472 mkt_quantity:  40
# Creating summary stats...
# *****performance.py: 1. create_sharpe_ratio*****
# *****performance.py: 2. create_drawdowns*****
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# /Users/miaoyuesun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:43: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Creating equity curve...
#                     IEI         cash  commission        total   returns  \
# datetime
# 2020-04-20  5336.799927  -850.487061           0  4486.312866  0.000982
# 2020-04-21     0.000000  4486.312866           0  4486.312866  0.000000
# 2020-04-22  5333.200073  -854.487305           0  4478.712769 -0.001694
# 2020-04-23     0.000000  4478.712769           0  4478.712769  0.000000
# 2020-04-24     0.000000  4478.712769           0  4478.712769  0.000000
# 2020-04-27     0.000000  4478.712769           0  4478.712769  0.000000
# 2020-04-28     0.000000  4478.712769           0  4478.712769  0.000000
# 2020-04-29     0.000000  4478.712769           0  4478.712769  0.000000
# 2020-04-30     0.000000  4478.712769           0  4478.712769  0.000000
# 2020-04-30     0.000000  4478.712769           0  4478.712769  0.000000
#
#             equity_curve  drawdown
# datetime
# 2020-04-20      1.495438  0.018880
# 2020-04-21      1.495438  0.018880
# 2020-04-22      1.492904  0.021413
# 2020-04-23      1.492904  0.021413
# 2020-04-24      1.492904  0.021413
# 2020-04-27      1.492904  0.021413
# 2020-04-28      1.492904  0.021413
# 2020-04-29      1.492904  0.021413
# 2020-04-30      1.492904  0.021413
# 2020-04-30      1.492904  0.021413
# None
# Signals: 296
# Orders: 296
# Fills: 296
# Position is empty:  2007-01-11
# Position is empty:  2007-01-12
# -------------------
# Opened the position:  2007-01-16
# Closed the position:  2007-01-17
# This trade's pnl: -8.09967041015625
# -------------------
# Position is empty:  2007-01-17
# Position is empty:  2007-01-18
# Position is empty:  2007-01-19
# Position is empty:  2007-01-22
# Position is empty:  2007-01-23
# Position is empty:  2007-01-24
# Position is empty:  2007-01-25
# Position is empty:  2007-01-26
# Position is empty:  2007-01-29
# Position is empty:  2007-01-30
# Position is empty:  2007-01-31
# Position is empty:  2007-02-01
# Position is empty:  2007-02-02
# -------------------
# Opened the position:  2007-02-05
# Holding the position:  2007-02-06
# Holding the position:  2007-02-07
# Holding the position:  2007-02-08
# Holding the position:  2007-02-09
# Holding the position:  2007-02-12
# Holding the position:  2007-02-13
# Holding the position:  2007-02-14
# Holding the position:  2007-02-15
# Holding the position:  2007-02-16
# Holding the position:  2007-02-20
# Holding the position:  2007-02-21
# Holding the position:  2007-02-22
# Holding the position:  2007-02-23
# Holding the position:  2007-02-26
# Holding the position:  2007-02-27
# Holding the position:  2007-02-28
# Holding the position:  2007-03-01
# Holding the position:  2007-03-02
# Holding the position:  2007-03-05
# Holding the position:  2007-03-06
# Holding the position:  2007-03-07
# Holding the position:  2007-03-08
# Holding the position:  2007-03-09
# Holding the position:  2007-03-12
# Holding the position:  2007-03-13
# Holding the position:  2007-03-14
# Holding the position:  2007-03-15
# Holding the position:  2007-03-16
# Holding the position:  2007-03-19
# Closed the position:  2007-03-20
# This trade's pnl: 47.50579833984375
# -------------------
# Position is empty:  2007-03-20
# Position is empty:  2007-03-21
# Position is empty:  2007-03-22
# Position is empty:  2007-03-23
# Position is empty:  2007-03-26
# Position is empty:  2007-03-27
# Position is empty:  2007-03-28
# Position is empty:  2007-03-29
# Position is empty:  2007-03-30
# Position is empty:  2007-04-02
# Position is empty:  2007-04-03
# Position is empty:  2007-04-04
# Position is empty:  2007-04-05
# Position is empty:  2007-04-09
# Position is empty:  2007-04-10
# Position is empty:  2007-04-11
# Position is empty:  2007-04-12
# Position is empty:  2007-04-13
# Position is empty:  2007-04-16
# Position is empty:  2007-04-17
# Position is empty:  2007-04-18
# -------------------
# Opened the position:  2007-04-19
# Holding the position:  2007-04-20
# Holding the position:  2007-04-23
# Holding the position:  2007-04-24
# Holding the position:  2007-04-25
# Holding the position:  2007-04-26
# Holding the position:  2007-04-27
# Holding the position:  2007-04-30
# Holding the position:  2007-05-01
# Holding the position:  2007-05-02
# Holding the position:  2007-05-03
# Holding the position:  2007-05-04
# Holding the position:  2007-05-07
# Holding the position:  2007-05-08
# Holding the position:  2007-05-09
# Holding the position:  2007-05-10
# Holding the position:  2007-05-11
# Holding the position:  2007-05-14
# Closed the position:  2007-05-15
# This trade's pnl: -3.40423583984375
# -------------------
# Position is empty:  2007-05-15
# Position is empty:  2007-05-16
# Position is empty:  2007-05-17
# Position is empty:  2007-05-18
# Position is empty:  2007-05-21
# Position is empty:  2007-05-22
# Position is empty:  2007-05-23
# Position is empty:  2007-05-24
# Position is empty:  2007-05-25
# Position is empty:  2007-05-29
# Position is empty:  2007-05-30
# Position is empty:  2007-05-31
# Position is empty:  2007-06-01
# Position is empty:  2007-06-04
# Position is empty:  2007-06-05
# Position is empty:  2007-06-06
# Position is empty:  2007-06-07
# Position is empty:  2007-06-08
# Position is empty:  2007-06-11
# Position is empty:  2007-06-12
# Position is empty:  2007-06-13
# Position is empty:  2007-06-14
# Position is empty:  2007-06-15
# Position is empty:  2007-06-18
# Position is empty:  2007-06-19
# -------------------
# Opened the position:  2007-06-20
# Holding the position:  2007-06-21
# Holding the position:  2007-06-22
# Holding the position:  2007-06-25
# Holding the position:  2007-06-26
# Holding the position:  2007-06-27
# Holding the position:  2007-06-28
# Holding the position:  2007-06-29
# Holding the position:  2007-07-02
# Holding the position:  2007-07-03
# Holding the position:  2007-07-05
# Holding the position:  2007-07-06
# Holding the position:  2007-07-09
# Holding the position:  2007-07-10
# Holding the position:  2007-07-11
# Holding the position:  2007-07-12
# Holding the position:  2007-07-13
# Holding the position:  2007-07-16
# Holding the position:  2007-07-17
# Holding the position:  2007-07-18
# Holding the position:  2007-07-19
# Holding the position:  2007-07-20
# Holding the position:  2007-07-23
# Holding the position:  2007-07-24
# Holding the position:  2007-07-25
# Holding the position:  2007-07-26
# Holding the position:  2007-07-27
# Holding the position:  2007-07-30
# Holding the position:  2007-07-31
# Holding the position:  2007-08-01
# Holding the position:  2007-08-02
# Holding the position:  2007-08-03
# Holding the position:  2007-08-06
# Holding the position:  2007-08-07
# Holding the position:  2007-08-08
# Holding the position:  2007-08-09
# Holding the position:  2007-08-10
# Closed the position:  2007-08-13
# This trade's pnl: 64.149169921875
# -------------------
# Position is empty:  2007-08-13
# -------------------
# Opened the position:  2007-08-14
# Holding the position:  2007-08-15
# Holding the position:  2007-08-16
# Holding the position:  2007-08-17
# Holding the position:  2007-08-20
# Holding the position:  2007-08-21
# Holding the position:  2007-08-22
# Holding the position:  2007-08-23
# Holding the position:  2007-08-24
# Holding the position:  2007-08-27
# Holding the position:  2007-08-28
# Holding the position:  2007-08-29
# Holding the position:  2007-08-30
# Holding the position:  2007-08-31
# Holding the position:  2007-09-04
# Holding the position:  2007-09-05
# Holding the position:  2007-09-06
# Holding the position:  2007-09-07
# Holding the position:  2007-09-10
# Holding the position:  2007-09-11
# Holding the position:  2007-09-12
# Holding the position:  2007-09-13
# Holding the position:  2007-09-14
# Holding the position:  2007-09-17
# Closed the position:  2007-09-18
# This trade's pnl: 58.56170654296875
# -------------------
# Position is empty:  2007-09-18
# Position is empty:  2007-09-19
# -------------------
# Opened the position:  2007-09-20
# Closed the position:  2007-09-21
# This trade's pnl: -28.9166259765625
# -------------------
# Position is empty:  2007-09-21
# Position is empty:  2007-09-24
# Position is empty:  2007-09-25
# Position is empty:  2007-09-26
# Position is empty:  2007-09-27
# Position is empty:  2007-09-28
# Position is empty:  2007-10-01
# Position is empty:  2007-10-02
# Position is empty:  2007-10-03
# -------------------
# Opened the position:  2007-10-04
# Holding the position:  2007-10-05
# Closed the position:  2007-10-08
# This trade's pnl: -17.1630859375
# -------------------
# Position is empty:  2007-10-08
# Position is empty:  2007-10-09
# Position is empty:  2007-10-10
# Position is empty:  2007-10-11
# Position is empty:  2007-10-12
# Position is empty:  2007-10-15
# Position is empty:  2007-10-16
# Position is empty:  2007-10-17
# -------------------
# Opened the position:  2007-10-18
# Holding the position:  2007-10-19
# Holding the position:  2007-10-22
# Holding the position:  2007-10-23
# Holding the position:  2007-10-24
# Holding the position:  2007-10-25
# Holding the position:  2007-10-26
# Holding the position:  2007-10-29
# Holding the position:  2007-10-30
# Holding the position:  2007-10-31
# Holding the position:  2007-11-01
# Holding the position:  2007-11-02
# Holding the position:  2007-11-05
# Holding the position:  2007-11-06
# Holding the position:  2007-11-07
# Holding the position:  2007-11-08
# Holding the position:  2007-11-09
# Holding the position:  2007-11-12
# Holding the position:  2007-11-13
# Holding the position:  2007-11-14
# Holding the position:  2007-11-15
# Holding the position:  2007-11-16
# Holding the position:  2007-11-19
# Holding the position:  2007-11-20
# Holding the position:  2007-11-21
# Holding the position:  2007-11-23
# Holding the position:  2007-11-26
# Holding the position:  2007-11-27
# Holding the position:  2007-11-28
# Holding the position:  2007-11-29
# Holding the position:  2007-11-30
# Holding the position:  2007-12-03
# Holding the position:  2007-12-04
# Holding the position:  2007-12-05
# Holding the position:  2007-12-06
# Holding the position:  2007-12-07
# Closed the position:  2007-12-10
# This trade's pnl: 115.7525634765625
# -------------------
# Position is empty:  2007-12-10
# Position is empty:  2007-12-11
# Position is empty:  2007-12-12
# Position is empty:  2007-12-13
# Position is empty:  2007-12-14
# Position is empty:  2007-12-17
# Position is empty:  2007-12-18
# Position is empty:  2007-12-19
# Position is empty:  2007-12-20
# Position is empty:  2007-12-21
# Position is empty:  2007-12-24
# Position is empty:  2007-12-26
# Position is empty:  2007-12-27
# Position is empty:  2007-12-28
# Position is empty:  2007-12-31
# -------------------
# Opened the position:  2008-01-02
# Holding the position:  2008-01-03
# Holding the position:  2008-01-04
# Holding the position:  2008-01-07
# Holding the position:  2008-01-08
# Holding the position:  2008-01-09
# Holding the position:  2008-01-10
# Holding the position:  2008-01-11
# Holding the position:  2008-01-14
# Holding the position:  2008-01-15
# Holding the position:  2008-01-16
# Holding the position:  2008-01-17
# Holding the position:  2008-01-18
# Holding the position:  2008-01-22
# Holding the position:  2008-01-23
# Holding the position:  2008-01-24
# Holding the position:  2008-01-25
# Holding the position:  2008-01-28
# Holding the position:  2008-01-29
# Holding the position:  2008-01-30
# Closed the position:  2008-01-31
# This trade's pnl: 82.92144775390625
# -------------------
# Position is empty:  2008-01-31
# Position is empty:  2008-02-01
# Position is empty:  2008-02-04
# Position is empty:  2008-02-05
# -------------------
# Opened the position:  2008-02-06
# Holding the position:  2008-02-07
# Closed the position:  2008-02-08
# This trade's pnl: -29.30511474609375
# -------------------
# Position is empty:  2008-02-08
# Position is empty:  2008-02-11
# -------------------
# Opened the position:  2008-02-12
# Holding the position:  2008-02-13
# Closed the position:  2008-02-14
# This trade's pnl: -12.45330810546875
# -------------------
# Position is empty:  2008-02-14
# Position is empty:  2008-02-15
# Position is empty:  2008-02-19
# Position is empty:  2008-02-20
# Position is empty:  2008-02-21
# Position is empty:  2008-02-22
# Position is empty:  2008-02-25
# Position is empty:  2008-02-26
# Position is empty:  2008-02-27
# Position is empty:  2008-02-28
# -------------------
# Opened the position:  2008-02-29
# Holding the position:  2008-03-03
# Holding the position:  2008-03-04
# Holding the position:  2008-03-05
# Holding the position:  2008-03-06
# Holding the position:  2008-03-07
# Holding the position:  2008-03-10
# Holding the position:  2008-03-11
# Holding the position:  2008-03-12
# Holding the position:  2008-03-13
# Holding the position:  2008-03-14
# Holding the position:  2008-03-17
# Holding the position:  2008-03-18
# Holding the position:  2008-03-19
# Holding the position:  2008-03-20
# Holding the position:  2008-03-24
# Holding the position:  2008-03-25
# Closed the position:  2008-03-26
# This trade's pnl: 30.1055908203125
# -------------------
# Position is empty:  2008-03-26
# Position is empty:  2008-03-27
# Position is empty:  2008-03-28
# Position is empty:  2008-03-31
# Position is empty:  2008-04-01
# Position is empty:  2008-04-02
# Position is empty:  2008-04-03
# Position is empty:  2008-04-04
# Position is empty:  2008-04-07
# Position is empty:  2008-04-08
# Position is empty:  2008-04-09
# Position is empty:  2008-04-10
# Position is empty:  2008-04-11
# Position is empty:  2008-04-14
# Position is empty:  2008-04-15
# Position is empty:  2008-04-16
# Position is empty:  2008-04-17
# Position is empty:  2008-04-18
# Position is empty:  2008-04-21
# Position is empty:  2008-04-22
# Position is empty:  2008-04-23
# Position is empty:  2008-04-24
# Position is empty:  2008-04-25
# Position is empty:  2008-04-28
# Position is empty:  2008-04-29
# Position is empty:  2008-04-30
# Position is empty:  2008-05-01
# Position is empty:  2008-05-02
# Position is empty:  2008-05-05
# Position is empty:  2008-05-06
# Position is empty:  2008-05-07
# Position is empty:  2008-05-08
# -------------------
# Opened the position:  2008-05-09
# Holding the position:  2008-05-12
# Holding the position:  2008-05-13
# Holding the position:  2008-05-14
# Holding the position:  2008-05-15
# Holding the position:  2008-05-16
# Holding the position:  2008-05-19
# Holding the position:  2008-05-20
# Holding the position:  2008-05-21
# Holding the position:  2008-05-22
# Holding the position:  2008-05-23
# Holding the position:  2008-05-27
# Closed the position:  2008-05-28
# This trade's pnl: -39.91455078125
# -------------------
# Position is empty:  2008-05-28
# Position is empty:  2008-05-29
# Position is empty:  2008-05-30
# Position is empty:  2008-06-02
# Position is empty:  2008-06-03
# Position is empty:  2008-06-04
# Position is empty:  2008-06-05
# Position is empty:  2008-06-06
# -------------------
# Opened the position:  2008-06-09
# Closed the position:  2008-06-10
# This trade's pnl: -33.46466064453125
# -------------------
# Position is empty:  2008-06-10
# Position is empty:  2008-06-11
# Position is empty:  2008-06-12
# Position is empty:  2008-06-13
# Position is empty:  2008-06-16
# Position is empty:  2008-06-17
# Position is empty:  2008-06-18
# Position is empty:  2008-06-19
# Position is empty:  2008-06-20
# Position is empty:  2008-06-23
# Position is empty:  2008-06-24
# -------------------
# Opened the position:  2008-06-25
# Holding the position:  2008-06-26
# Holding the position:  2008-06-27
# Holding the position:  2008-06-30
# Holding the position:  2008-07-01
# Holding the position:  2008-07-02
# Holding the position:  2008-07-03
# Holding the position:  2008-07-07
# Holding the position:  2008-07-08
# Holding the position:  2008-07-09
# Holding the position:  2008-07-10
# Holding the position:  2008-07-11
# Holding the position:  2008-07-14
# Holding the position:  2008-07-15
# Holding the position:  2008-07-16
# Holding the position:  2008-07-17
# Holding the position:  2008-07-18
# Closed the position:  2008-07-21
# This trade's pnl: 21.3873291015625
# -------------------
# Position is empty:  2008-07-21
# Position is empty:  2008-07-22
# Position is empty:  2008-07-23
# Position is empty:  2008-07-24
# Position is empty:  2008-07-25
# Position is empty:  2008-07-28
# Position is empty:  2008-07-29
# Position is empty:  2008-07-30
# Position is empty:  2008-07-31
# Position is empty:  2008-08-01
# -------------------
# Opened the position:  2008-08-04
# Holding the position:  2008-08-05
# Holding the position:  2008-08-06
# Holding the position:  2008-08-07
# Holding the position:  2008-08-08
# Holding the position:  2008-08-11
# Holding the position:  2008-08-12
# Holding the position:  2008-08-13
# Holding the position:  2008-08-14
# Holding the position:  2008-08-15
# Holding the position:  2008-08-18
# Holding the position:  2008-08-19
# Holding the position:  2008-08-20
# Holding the position:  2008-08-21
# Holding the position:  2008-08-22
# Holding the position:  2008-08-25
# Holding the position:  2008-08-26
# Holding the position:  2008-08-27
# Holding the position:  2008-08-28
# Holding the position:  2008-08-29
# Holding the position:  2008-09-02
# Holding the position:  2008-09-03
# Holding the position:  2008-09-04
# Holding the position:  2008-09-05
# Holding the position:  2008-09-08
# Holding the position:  2008-09-09
# Holding the position:  2008-09-10
# Holding the position:  2008-09-11
# Holding the position:  2008-09-12
# Holding the position:  2008-09-15
# Holding the position:  2008-09-16
# Holding the position:  2008-09-17
# Holding the position:  2008-09-18
# Holding the position:  2008-09-19
# Holding the position:  2008-09-22
# Closed the position:  2008-09-23
# This trade's pnl: 43.88580322265625
# -------------------
# Position is empty:  2008-09-23
# Position is empty:  2008-09-24
# Position is empty:  2008-09-25
# Position is empty:  2008-09-26
# Position is empty:  2008-09-29
# Position is empty:  2008-09-30
# Position is empty:  2008-10-01
# Position is empty:  2008-10-02
# -------------------
# Opened the position:  2008-10-03
# Holding the position:  2008-10-06
# Holding the position:  2008-10-07
# Holding the position:  2008-10-08
# Holding the position:  2008-10-09
# Holding the position:  2008-10-10
# Holding the position:  2008-10-13
# Closed the position:  2008-10-14
# This trade's pnl: -68.1170654296875
# -------------------
# Position is empty:  2008-10-14
# Position is empty:  2008-10-15
# Position is empty:  2008-10-16
# Position is empty:  2008-10-17
# Position is empty:  2008-10-20
# Position is empty:  2008-10-21
# -------------------
# Opened the position:  2008-10-22
# Holding the position:  2008-10-23
# Holding the position:  2008-10-24
# Holding the position:  2008-10-27
# Holding the position:  2008-10-28
# Holding the position:  2008-10-29
# Holding the position:  2008-10-30
# Closed the position:  2008-10-31
# This trade's pnl: -15.24566650390625
# -------------------
# Position is empty:  2008-10-31
# Position is empty:  2008-11-03
# -------------------
# Opened the position:  2008-11-04
# Holding the position:  2008-11-05
# Holding the position:  2008-11-06
# Holding the position:  2008-11-07
# Holding the position:  2008-11-10
# Holding the position:  2008-11-11
# Holding the position:  2008-11-12
# Holding the position:  2008-11-13
# Holding the position:  2008-11-14
# Holding the position:  2008-11-17
# Holding the position:  2008-11-18
# Holding the position:  2008-11-19
# Holding the position:  2008-11-20
# Holding the position:  2008-11-21
# Holding the position:  2008-11-24
# Holding the position:  2008-11-25
# Holding the position:  2008-11-26
# Holding the position:  2008-11-28
# Holding the position:  2008-12-01
# Holding the position:  2008-12-02
# Holding the position:  2008-12-03
# Holding the position:  2008-12-04
# Holding the position:  2008-12-05
# Holding the position:  2008-12-08
# Holding the position:  2008-12-09
# Holding the position:  2008-12-10
# Holding the position:  2008-12-11
# Holding the position:  2008-12-12
# Holding the position:  2008-12-15
# Holding the position:  2008-12-16
# Holding the position:  2008-12-17
# Holding the position:  2008-12-18
# Holding the position:  2008-12-19
# Holding the position:  2008-12-22
# Holding the position:  2008-12-23
# Closed the position:  2008-12-24
# This trade's pnl: 189.76104736328125
# -------------------
# Position is empty:  2008-12-24
# Position is empty:  2008-12-26
# Position is empty:  2008-12-29
# Position is empty:  2008-12-30
# Position is empty:  2008-12-31
# Position is empty:  2009-01-02
# Position is empty:  2009-01-05
# Position is empty:  2009-01-06
# Position is empty:  2009-01-07
# Position is empty:  2009-01-08
# Position is empty:  2009-01-09
# Position is empty:  2009-01-12
# -------------------
# Opened the position:  2009-01-13
# Closed the position:  2009-01-14
# This trade's pnl: -6.664733886718295
# -------------------
# Position is empty:  2009-01-14
# -------------------
# Opened the position:  2009-01-15
# Holding the position:  2009-01-16
# Holding the position:  2009-01-20
# Holding the position:  2009-01-21
# Closed the position:  2009-01-22
# This trade's pnl: -42.289123535156705
# -------------------
# Position is empty:  2009-01-22
# Position is empty:  2009-01-23
# Position is empty:  2009-01-26
# Position is empty:  2009-01-27
# Position is empty:  2009-01-28
# Position is empty:  2009-01-29
# Position is empty:  2009-01-30
# Position is empty:  2009-02-02
# Position is empty:  2009-02-03
# Position is empty:  2009-02-04
# Position is empty:  2009-02-05
# Position is empty:  2009-02-06
# Position is empty:  2009-02-09
# Position is empty:  2009-02-10
# Position is empty:  2009-02-11
# Position is empty:  2009-02-12
# Position is empty:  2009-02-13
# Position is empty:  2009-02-17
# -------------------
# Opened the position:  2009-02-18
# Holding the position:  2009-02-19
# Holding the position:  2009-02-20
# Holding the position:  2009-02-23
# Holding the position:  2009-02-24
# Holding the position:  2009-02-25
# Holding the position:  2009-02-26
# Closed the position:  2009-02-27
# This trade's pnl: -61.06170654296875
# -------------------
# Position is empty:  2009-02-27
# Position is empty:  2009-03-02
# -------------------
# Opened the position:  2009-03-03
# Holding the position:  2009-03-04
# Holding the position:  2009-03-05
# Holding the position:  2009-03-06
# Holding the position:  2009-03-09
# Holding the position:  2009-03-10
# Holding the position:  2009-03-11
# Closed the position:  2009-03-12
# This trade's pnl: -26.396789550779886
# -------------------
# Position is empty:  2009-03-12
# Position is empty:  2009-03-13
# Position is empty:  2009-03-16
# Position is empty:  2009-03-17
# Position is empty:  2009-03-18
# -------------------
# Opened the position:  2009-03-19
# Holding the position:  2009-03-20
# Holding the position:  2009-03-23
# Holding the position:  2009-03-24
# Holding the position:  2009-03-25
# Holding the position:  2009-03-26
# Holding the position:  2009-03-27
# Holding the position:  2009-03-30
# Holding the position:  2009-03-31
# Holding the position:  2009-04-01
# Holding the position:  2009-04-02
# Holding the position:  2009-04-03
# Closed the position:  2009-04-06
# This trade's pnl: -46.00982666015625
# -------------------
# Position is empty:  2009-04-06
# Position is empty:  2009-04-07
# Position is empty:  2009-04-08
# Position is empty:  2009-04-09
# Position is empty:  2009-04-13
# Position is empty:  2009-04-14
# Position is empty:  2009-04-15
# Position is empty:  2009-04-16
# Position is empty:  2009-04-17
# Position is empty:  2009-04-20
# Position is empty:  2009-04-21
# Position is empty:  2009-04-22
# Position is empty:  2009-04-23
# Position is empty:  2009-04-24
# Position is empty:  2009-04-27
# Position is empty:  2009-04-28
# Position is empty:  2009-04-29
# Position is empty:  2009-04-30
# Position is empty:  2009-05-01
# Position is empty:  2009-05-04
# Position is empty:  2009-05-05
# Position is empty:  2009-05-06
# Position is empty:  2009-05-07
# Position is empty:  2009-05-08
# Position is empty:  2009-05-11
# Position is empty:  2009-05-12
# Position is empty:  2009-05-13
# -------------------
# Opened the position:  2009-05-14
# Holding the position:  2009-05-15
# Holding the position:  2009-05-18
# Holding the position:  2009-05-19
# Holding the position:  2009-05-20
# Holding the position:  2009-05-21
# Holding the position:  2009-05-22
# Closed the position:  2009-05-26
# This trade's pnl: -40.240478515625
# -------------------
# Position is empty:  2009-05-26
# Position is empty:  2009-05-27
# Position is empty:  2009-05-28
# Position is empty:  2009-05-29
# Position is empty:  2009-06-01
# Position is empty:  2009-06-02
# Position is empty:  2009-06-03
# Position is empty:  2009-06-04
# Position is empty:  2009-06-05
# Position is empty:  2009-06-08
# Position is empty:  2009-06-09
# Position is empty:  2009-06-10
# Position is empty:  2009-06-11
# Position is empty:  2009-06-12
# Position is empty:  2009-06-15
# Position is empty:  2009-06-16
# Position is empty:  2009-06-17
# -------------------
# Opened the position:  2009-06-18
# Holding the position:  2009-06-19
# Holding the position:  2009-06-22
# Holding the position:  2009-06-23
# Holding the position:  2009-06-24
# Holding the position:  2009-06-25
# Holding the position:  2009-06-26
# Holding the position:  2009-06-29
# Holding the position:  2009-06-30
# Holding the position:  2009-07-01
# Holding the position:  2009-07-02
# Holding the position:  2009-07-06
# Holding the position:  2009-07-07
# Holding the position:  2009-07-08
# Holding the position:  2009-07-09
# Holding the position:  2009-07-10
# Holding the position:  2009-07-13
# Holding the position:  2009-07-14
# Holding the position:  2009-07-15
# Closed the position:  2009-07-16
# This trade's pnl: 23.62426757812409
# -------------------
# Position is empty:  2009-07-16
# Position is empty:  2009-07-17
# Position is empty:  2009-07-20
# Position is empty:  2009-07-21
# Position is empty:  2009-07-22
# Position is empty:  2009-07-23
# Position is empty:  2009-07-24
# Position is empty:  2009-07-27
# Position is empty:  2009-07-28
# Position is empty:  2009-07-29
# Position is empty:  2009-07-30
# Position is empty:  2009-07-31
# Position is empty:  2009-08-03
# Position is empty:  2009-08-04
# Position is empty:  2009-08-05
# Position is empty:  2009-08-06
# Position is empty:  2009-08-07
# Position is empty:  2009-08-10
# Position is empty:  2009-08-11
# Position is empty:  2009-08-12
# -------------------
# Opened the position:  2009-08-13
# Holding the position:  2009-08-14
# Holding the position:  2009-08-17
# Holding the position:  2009-08-18
# Holding the position:  2009-08-19
# Holding the position:  2009-08-20
# Holding the position:  2009-08-21
# Holding the position:  2009-08-24
# Holding the position:  2009-08-25
# Holding the position:  2009-08-26
# Holding the position:  2009-08-27
# Holding the position:  2009-08-28
# Holding the position:  2009-08-31
# Holding the position:  2009-09-01
# Holding the position:  2009-09-02
# Holding the position:  2009-09-03
# Holding the position:  2009-09-04
# Holding the position:  2009-09-08
# Holding the position:  2009-09-09
# Holding the position:  2009-09-10
# Holding the position:  2009-09-11
# Holding the position:  2009-09-14
# Closed the position:  2009-09-15
# This trade's pnl: 61.46087646484375
# -------------------
# Position is empty:  2009-09-15
# Position is empty:  2009-09-16
# Position is empty:  2009-09-17
# Position is empty:  2009-09-18
# Position is empty:  2009-09-21
# Position is empty:  2009-09-22
# Position is empty:  2009-09-23
# Position is empty:  2009-09-24
# Position is empty:  2009-09-25
# -------------------
# Opened the position:  2009-09-28
# Holding the position:  2009-09-29
# Holding the position:  2009-09-30
# Holding the position:  2009-10-01
# Holding the position:  2009-10-02
# Holding the position:  2009-10-05
# Holding the position:  2009-10-06
# Holding the position:  2009-10-07
# Holding the position:  2009-10-08
# Holding the position:  2009-10-09
# Holding the position:  2009-10-12
# Holding the position:  2009-10-13
# Closed the position:  2009-10-14
# This trade's pnl: 13.85772705078125
# -------------------
# Position is empty:  2009-10-14
# Position is empty:  2009-10-15
# Position is empty:  2009-10-16
# Position is empty:  2009-10-19
# Position is empty:  2009-10-20
# Position is empty:  2009-10-21
# Position is empty:  2009-10-22
# Position is empty:  2009-10-23
# Position is empty:  2009-10-26
# Position is empty:  2009-10-27
# Position is empty:  2009-10-28
# Position is empty:  2009-10-29
# Position is empty:  2009-10-30
# Position is empty:  2009-11-02
# -------------------
# Opened the position:  2009-11-03
# Holding the position:  2009-11-04
# Holding the position:  2009-11-05
# Holding the position:  2009-11-06
# Holding the position:  2009-11-09
# Holding the position:  2009-11-10
# Holding the position:  2009-11-11
# Holding the position:  2009-11-12
# Holding the position:  2009-11-13
# Holding the position:  2009-11-16
# ...
# Holding the position:  2018-08-20
# Holding the position:  2018-08-21
# Holding the position:  2018-08-22
# Holding the position:  2018-08-23
# Holding the position:  2018-08-24
# Holding the position:  2018-08-27
# Holding the position:  2018-08-28
# Holding the position:  2018-08-29
# Closed the position:  2018-08-30
# This trade's pnl: 6.2197875976571595
# -------------------
# Position is empty:  2018-08-30
# Position is empty:  2018-08-31
# Position is empty:  2018-09-04
# Position is empty:  2018-09-05
# Position is empty:  2018-09-06
# Position is empty:  2018-09-07
# Position is empty:  2018-09-10
# Position is empty:  2018-09-11
# Position is empty:  2018-09-12
# Position is empty:  2018-09-13
# Position is empty:  2018-09-14
# Position is empty:  2018-09-17
# Position is empty:  2018-09-18
# Position is empty:  2018-09-19
# Position is empty:  2018-09-20
# Position is empty:  2018-09-21
# Position is empty:  2018-09-24
# Position is empty:  2018-09-25
# Position is empty:  2018-09-26
# Position is empty:  2018-09-27
# Position is empty:  2018-09-28
# -------------------
# Opened the position:  2018-10-01
# Holding the position:  2018-10-02
# Holding the position:  2018-10-03
# Closed the position:  2018-10-04
# This trade's pnl: -19.404296875
# -------------------
# Position is empty:  2018-10-04
# Position is empty:  2018-10-05
# Position is empty:  2018-10-08
# Position is empty:  2018-10-09
# Position is empty:  2018-10-10
# Position is empty:  2018-10-11
# -------------------
# Opened the position:  2018-10-12
# Holding the position:  2018-10-15
# Holding the position:  2018-10-16
# Holding the position:  2018-10-17
# Holding the position:  2018-10-18
# Holding the position:  2018-10-19
# Holding the position:  2018-10-22
# Holding the position:  2018-10-23
# Holding the position:  2018-10-24
# Holding the position:  2018-10-25
# Holding the position:  2018-10-26
# Holding the position:  2018-10-29
# Holding the position:  2018-10-30
# Holding the position:  2018-10-31
# Holding the position:  2018-11-01
# Holding the position:  2018-11-02
# Holding the position:  2018-11-05
# Closed the position:  2018-11-06
# This trade's pnl: -2.7249145507807953
# -------------------
# Position is empty:  2018-11-06
# Position is empty:  2018-11-07
# Position is empty:  2018-11-08
# Position is empty:  2018-11-09
# Position is empty:  2018-11-12
# Position is empty:  2018-11-13
# Position is empty:  2018-11-14
# -------------------
# Opened the position:  2018-11-15
# Holding the position:  2018-11-16
# Holding the position:  2018-11-19
# Holding the position:  2018-11-20
# Holding the position:  2018-11-21
# Holding the position:  2018-11-23
# Holding the position:  2018-11-26
# Holding the position:  2018-11-27
# Holding the position:  2018-11-28
# Holding the position:  2018-11-29
# Holding the position:  2018-11-30
# Holding the position:  2018-12-03
# Holding the position:  2018-12-04
# Holding the position:  2018-12-06
# Holding the position:  2018-12-07
# Holding the position:  2018-12-10
# Holding the position:  2018-12-11
# Holding the position:  2018-12-12
# Holding the position:  2018-12-13
# Holding the position:  2018-12-14
# Holding the position:  2018-12-17
# Holding the position:  2018-12-18
# Holding the position:  2018-12-19
# Holding the position:  2018-12-20
# Holding the position:  2018-12-21
# Holding the position:  2018-12-24
# Holding the position:  2018-12-26
# Holding the position:  2018-12-27
# Holding the position:  2018-12-28
# Holding the position:  2018-12-31
# Holding the position:  2019-01-02
# Holding the position:  2019-01-03
# Holding the position:  2019-01-04
# Holding the position:  2019-01-07
# Holding the position:  2019-01-08
# Holding the position:  2019-01-09
# Holding the position:  2019-01-10
# Closed the position:  2019-01-11
# This trade's pnl: 97.0309448242183
# -------------------
# Position is empty:  2019-01-11
# Position is empty:  2019-01-14
# Position is empty:  2019-01-15
# Position is empty:  2019-01-16
# Position is empty:  2019-01-17
# Position is empty:  2019-01-18
# Position is empty:  2019-01-22
# Position is empty:  2019-01-23
# Position is empty:  2019-01-24
# Position is empty:  2019-01-25
# Position is empty:  2019-01-28
# Position is empty:  2019-01-29
# Position is empty:  2019-01-30
# -------------------
# Opened the position:  2019-01-31
# Holding the position:  2019-02-01
# Holding the position:  2019-02-04
# Holding the position:  2019-02-05
# Holding the position:  2019-02-06
# Holding the position:  2019-02-07
# Holding the position:  2019-02-08
# Holding the position:  2019-02-11
# Holding the position:  2019-02-12
# Holding the position:  2019-02-13
# Holding the position:  2019-02-14
# Holding the position:  2019-02-15
# Holding the position:  2019-02-19
# Holding the position:  2019-02-20
# Holding the position:  2019-02-21
# Holding the position:  2019-02-22
# Holding the position:  2019-02-25
# Holding the position:  2019-02-26
# Closed the position:  2019-02-27
# This trade's pnl: 11.400146484373636
# -------------------
# Position is empty:  2019-02-27
# Position is empty:  2019-02-28
# Position is empty:  2019-03-01
# Position is empty:  2019-03-04
# Position is empty:  2019-03-05
# Position is empty:  2019-03-06
# Position is empty:  2019-03-07
# -------------------
# Opened the position:  2019-03-08
# Holding the position:  2019-03-11
# Holding the position:  2019-03-12
# Holding the position:  2019-03-13
# Holding the position:  2019-03-14
# Holding the position:  2019-03-15
# Holding the position:  2019-03-18
# Holding the position:  2019-03-19
# Holding the position:  2019-03-20
# Holding the position:  2019-03-21
# Holding the position:  2019-03-22
# Holding the position:  2019-03-25
# Holding the position:  2019-03-26
# Holding the position:  2019-03-27
# Holding the position:  2019-03-28
# Holding the position:  2019-03-29
# Holding the position:  2019-04-01
# Holding the position:  2019-04-02
# Holding the position:  2019-04-03
# Closed the position:  2019-04-04
# This trade's pnl: 31.36169433593841
# -------------------
# Position is empty:  2019-04-04
# Position is empty:  2019-04-05
# Position is empty:  2019-04-08
# Position is empty:  2019-04-09
# Position is empty:  2019-04-10
# Position is empty:  2019-04-11
# Position is empty:  2019-04-12
# Position is empty:  2019-04-15
# Position is empty:  2019-04-16
# Position is empty:  2019-04-17
# Position is empty:  2019-04-18
# Position is empty:  2019-04-22
# Position is empty:  2019-04-23
# Position is empty:  2019-04-24
# Position is empty:  2019-04-25
# -------------------
# Opened the position:  2019-04-26
# Holding the position:  2019-04-29
# Holding the position:  2019-04-30
# Holding the position:  2019-05-01
# Holding the position:  2019-05-02
# Holding the position:  2019-05-03
# Holding the position:  2019-05-06
# Holding the position:  2019-05-07
# Holding the position:  2019-05-08
# Holding the position:  2019-05-09
# Holding the position:  2019-05-10
# Holding the position:  2019-05-13
# Holding the position:  2019-05-14
# Holding the position:  2019-05-15
# Holding the position:  2019-05-16
# Holding the position:  2019-05-17
# Holding the position:  2019-05-20
# Holding the position:  2019-05-21
# Holding the position:  2019-05-22
# Holding the position:  2019-05-23
# Holding the position:  2019-05-24
# Holding the position:  2019-05-28
# Holding the position:  2019-05-29
# Holding the position:  2019-05-30
# Holding the position:  2019-05-31
# Holding the position:  2019-06-03
# Holding the position:  2019-06-04
# Holding the position:  2019-06-05
# Holding the position:  2019-06-06
# Holding the position:  2019-06-07
# Holding the position:  2019-06-10
# Holding the position:  2019-06-11
# Holding the position:  2019-06-12
# Holding the position:  2019-06-13
# Holding the position:  2019-06-14
# Holding the position:  2019-06-17
# Holding the position:  2019-06-18
# Holding the position:  2019-06-19
# Holding the position:  2019-06-20
# Holding the position:  2019-06-21
# Holding the position:  2019-06-24
# Holding the position:  2019-06-25
# Holding the position:  2019-06-26
# Closed the position:  2019-06-27
# This trade's pnl: 126.143798828125
# -------------------
# Position is empty:  2019-06-27
# Position is empty:  2019-06-28
# -------------------
# Opened the position:  2019-07-01
# Closed the position:  2019-07-02
# This trade's pnl: -9.22210693359375
# -------------------
# Position is empty:  2019-07-02
# Position is empty:  2019-07-03
# Position is empty:  2019-07-05
# Position is empty:  2019-07-08
# Position is empty:  2019-07-09
# Position is empty:  2019-07-10
# Position is empty:  2019-07-11
# Position is empty:  2019-07-12
# Position is empty:  2019-07-15
# Position is empty:  2019-07-16
# Position is empty:  2019-07-17
# Position is empty:  2019-07-18
# Position is empty:  2019-07-19
# -------------------
# Opened the position:  2019-07-22
# Holding the position:  2019-07-23
# Holding the position:  2019-07-24
# Holding the position:  2019-07-25
# Holding the position:  2019-07-26
# Holding the position:  2019-07-29
# Holding the position:  2019-07-30
# Holding the position:  2019-07-31
# Holding the position:  2019-08-01
# Holding the position:  2019-08-02
# Holding the position:  2019-08-05
# Holding the position:  2019-08-06
# Holding the position:  2019-08-07
# Holding the position:  2019-08-08
# Holding the position:  2019-08-09
# Holding the position:  2019-08-12
# Holding the position:  2019-08-13
# Holding the position:  2019-08-14
# Holding the position:  2019-08-15
# Holding the position:  2019-08-16
# Holding the position:  2019-08-19
# Holding the position:  2019-08-20
# Holding the position:  2019-08-21
# Holding the position:  2019-08-22
# Holding the position:  2019-08-23
# Holding the position:  2019-08-26
# Holding the position:  2019-08-27
# Holding the position:  2019-08-28
# Holding the position:  2019-08-29
# Closed the position:  2019-08-30
# This trade's pnl: 96.16363525390625
# -------------------
# Position is empty:  2019-08-30
# Position is empty:  2019-09-03
# Position is empty:  2019-09-04
# -------------------
# Opened the position:  2019-09-05
# Closed the position:  2019-09-06
# This trade's pnl: -31.92657470703125
# -------------------
# Position is empty:  2019-09-06
# Position is empty:  2019-09-09
# Position is empty:  2019-09-10
# Position is empty:  2019-09-11
# Position is empty:  2019-09-12
# Position is empty:  2019-09-13
# Position is empty:  2019-09-16
# Position is empty:  2019-09-17
# Position is empty:  2019-09-18
# Position is empty:  2019-09-19
# Position is empty:  2019-09-20
# Position is empty:  2019-09-23
# Position is empty:  2019-09-24
# -------------------
# Opened the position:  2019-09-25
# Holding the position:  2019-09-26
# Holding the position:  2019-09-27
# Holding the position:  2019-09-30
# Holding the position:  2019-10-01
# Holding the position:  2019-10-02
# Holding the position:  2019-10-03
# Holding the position:  2019-10-04
# Holding the position:  2019-10-07
# Holding the position:  2019-10-08
# Holding the position:  2019-10-09
# Holding the position:  2019-10-10
# Holding the position:  2019-10-11
# Holding the position:  2019-10-14
# Closed the position:  2019-10-15
# This trade's pnl: -8.56109619140716
# -------------------
# Position is empty:  2019-10-15
# Position is empty:  2019-10-16
# Position is empty:  2019-10-17
# Position is empty:  2019-10-18
# Position is empty:  2019-10-21
# Position is empty:  2019-10-22
# Position is empty:  2019-10-23
# Position is empty:  2019-10-24
# Position is empty:  2019-10-25
# Position is empty:  2019-10-28
# Position is empty:  2019-10-29
# Position is empty:  2019-10-30
# Position is empty:  2019-10-31
# Position is empty:  2019-11-01
# -------------------
# Opened the position:  2019-11-04
# Holding the position:  2019-11-05
# Holding the position:  2019-11-06
# Holding the position:  2019-11-07
# Closed the position:  2019-11-08
# This trade's pnl: -46.30889892578034
# -------------------
# Position is empty:  2019-11-08
# Position is empty:  2019-11-11
# Position is empty:  2019-11-12
# Position is empty:  2019-11-13
# Position is empty:  2019-11-14
# -------------------
# Opened the position:  2019-11-15
# Holding the position:  2019-11-18
# Holding the position:  2019-11-19
# Holding the position:  2019-11-20
# Holding the position:  2019-11-21
# Holding the position:  2019-11-22
# Holding the position:  2019-11-25
# Holding the position:  2019-11-26
# Holding the position:  2019-11-27
# Holding the position:  2019-11-29
# Holding the position:  2019-12-02
# Holding the position:  2019-12-03
# Holding the position:  2019-12-04
# Holding the position:  2019-12-05
# Holding the position:  2019-12-06
# Holding the position:  2019-12-09
# Closed the position:  2019-12-10
# This trade's pnl: -10.09521484374909
# -------------------
# Position is empty:  2019-12-10
# Position is empty:  2019-12-11
# Position is empty:  2019-12-12
# Position is empty:  2019-12-13
# Position is empty:  2019-12-16
# Position is empty:  2019-12-17
# Position is empty:  2019-12-18
# Position is empty:  2019-12-19
# Position is empty:  2019-12-20
# Position is empty:  2019-12-23
# Position is empty:  2019-12-24
# Position is empty:  2019-12-26
# Position is empty:  2019-12-27
# -------------------
# Opened the position:  2019-12-30
# Holding the position:  2019-12-31
# Holding the position:  2020-01-02
# Holding the position:  2020-01-03
# Holding the position:  2020-01-06
# Holding the position:  2020-01-07
# Holding the position:  2020-01-08
# Holding the position:  2020-01-09
# Holding the position:  2020-01-10
# Holding the position:  2020-01-13
# Holding the position:  2020-01-14
# Holding the position:  2020-01-15
# Holding the position:  2020-01-16
# Holding the position:  2020-01-17
# Holding the position:  2020-01-21
# Holding the position:  2020-01-22
# Holding the position:  2020-01-23
# Holding the position:  2020-01-24
# Holding the position:  2020-01-27
# Holding the position:  2020-01-28
# Holding the position:  2020-01-29
# Holding the position:  2020-01-30
# Holding the position:  2020-01-31
# Holding the position:  2020-02-03
# Holding the position:  2020-02-04
# Holding the position:  2020-02-05
# Holding the position:  2020-02-06
# Holding the position:  2020-02-07
# Holding the position:  2020-02-10
# Holding the position:  2020-02-11
# Holding the position:  2020-02-12
# Closed the position:  2020-02-13
# This trade's pnl: 57.46002197265534
# -------------------
# Position is empty:  2020-02-13
# Position is empty:  2020-02-14
# Position is empty:  2020-02-18
# Position is empty:  2020-02-19
# Position is empty:  2020-02-20
# Position is empty:  2020-02-21
# -------------------
# Opened the position:  2020-02-24
# Holding the position:  2020-02-25
# Holding the position:  2020-02-26
# Holding the position:  2020-02-27
# Holding the position:  2020-02-28
# Holding the position:  2020-03-02
# Holding the position:  2020-03-03
# Holding the position:  2020-03-04
# Holding the position:  2020-03-05
# Holding the position:  2020-03-06
# Holding the position:  2020-03-09
# Holding the position:  2020-03-10
# Holding the position:  2020-03-11
# Holding the position:  2020-03-12
# Holding the position:  2020-03-13
# Holding the position:  2020-03-16
# Holding the position:  2020-03-17
# Holding the position:  2020-03-18
# Closed the position:  2020-03-19
# This trade's pnl: 86.4019775390625
# -------------------
# Position is empty:  2020-03-19
# Position is empty:  2020-03-20
# Position is empty:  2020-03-23
# Position is empty:  2020-03-24
# Position is empty:  2020-03-25
# Position is empty:  2020-03-26
# -------------------
# Opened the position:  2020-03-27
# Holding the position:  2020-03-30
# Holding the position:  2020-03-31
# Holding the position:  2020-04-01
# Holding the position:  2020-04-02
# Holding the position:  2020-04-03
# Holding the position:  2020-04-06
# Holding the position:  2020-04-07
# Holding the position:  2020-04-08
# Holding the position:  2020-04-09
# Holding the position:  2020-04-13
# Holding the position:  2020-04-14
# Holding the position:  2020-04-15
# Holding the position:  2020-04-16
# Holding the position:  2020-04-17
# Holding the position:  2020-04-20
# Closed the position:  2020-04-21
# This trade's pnl: 35.84228515624909
# -------------------
# Position is empty:  2020-04-21
# -------------------
# Opened the position:  2020-04-22
# Closed the position:  2020-04-23
# This trade's pnl: -12.60009765624909
# -------------------
# Position is empty:  2020-04-23
# Position is empty:  2020-04-24
# Position is empty:  2020-04-27
# Position is empty:  2020-04-28
# Position is empty:  2020-04-29
# Position is empty:  2020-04-30
# total_commission:  0
# gross_profit:  738.71
# net_profit:  738.71
# commission_impact: 0.0%
# win %: 37.84
# PL Ratio: 2.34

# %%
pd.DataFrame(ticker_performances)
# Out:
#                       IEI
# PL Ratio             2.34
# commission_impact    0.0%
# gross_profit       738.71
# net_profit         738.71
# overall_score        0.26
# total_commission        0
# win %               37.84

# %%
data.tail(2)
# Out:
#               datetime  market_value          cash  commission         total  \
# datetime
# 2020-04-29  2020-04-29           0.0  31478.712769           0  31478.712769
# 2020-04-30  2020-04-30           0.0  31478.712769           0  31478.712769
#
#             returns  equity_curve  drawdown  daily_PL
# datetime
# 2020-04-29      0.0       1.04929  0.002141       0.0
# 2020-04-30      0.0       1.04929  0.002141       0.0

# %%
df_equity_copy['equity_curve'].plot(figsize = (16,5))

# %%
df_equity_copy['equity_curve'].plot(figsize = (16,5))

# %%
df_equity_copy['equity_curve'].plot(figsize = (16,5))
